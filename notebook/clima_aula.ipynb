# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = '../data/clima_aula.csv'
df = pd.read_csv(file)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7856 entries, 0 to 7855
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              7720 non-null   object
#  1   Provincia_IE           7719 non-null   object
#  2   UGEL_IE                7719 non-null   object
#  3   Distrito_IE            7719 non-null   object
#  4   CentroPoblado_IE       7719 non-null   object
#  5   Institucion_Educativa  7719 non-null   object
#  6   CodigoLocal_IE         7719 non-null   float64
#  7   CodigoModular_IE       7719 non-null   float64
#  8   Grado                  7854 non-null   object
#  9   Fecha                  7854 non-null   object
#  10  Evaluacion             7854 non-null   object
#  11  Elemento               7854 non-null   object
#  12  % Positivas            7829 non-null   object
#  13  Nivel de logro         7854 non-null   object
#  14  DNI_Participante       7705 non-null   object
#  15  ID_Participante        7719 non-null   object
#  16  Participante           7719 non-null   object
#  17  Estatus                7719 non-null   object
#  18  Coordinador/a          7719 non-null   object
#  19  Programa               7719 non-null   object
#  20  Año PDL                7719 non-null   float64
#  21  Socios                 7719 non-null   object
# dtypes: float64(3), object(19)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#        CodigoLocal_IE  CodigoModular_IE  Año PDL
# count     7719.000000      7.719000e+03   7719.0
# mean    152825.018396      5.788429e+05   2023.0
# std     157981.328381      3.469788e+05      0.0
# min        142.000000      2.171330e+05   2023.0
# 25%      24355.000000      3.645470e+05   2023.0
# 50%      71200.000000      4.264110e+05   2023.0
# 75%     256326.000000      6.765930e+05   2023.0
# max     823724.000000      1.794627e+06   2023.0

# %%
df = df.dropna()  # Elimina todas las filas con NaNs
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7680 entries, 135 to 7853
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              7680 non-null   object
#  1   Provincia_IE           7680 non-null   object
#  2   UGEL_IE                7680 non-null   object
#  3   Distrito_IE            7680 non-null   object
#  4   CentroPoblado_IE       7680 non-null   object
#  5   Institucion_Educativa  7680 non-null   object
#  6   CodigoLocal_IE         7680 non-null   float64
#  7   CodigoModular_IE       7680 non-null   float64
#  8   Grado                  7680 non-null   object
#  9   Fecha                  7680 non-null   object
#  10  Evaluacion             7680 non-null   object
#  11  Elemento               7680 non-null   object
#  12  % Positivas            7680 non-null   object
#  13  Nivel de logro         7680 non-null   object
#  14  DNI_Participante       7680 non-null   object
#  15  ID_Participante        7680 non-null   object
#  16  Participante           7680 non-null   object
#  17  Estatus                7680 non-null   object
#  18  Coordinador/a          7680 non-null   object
#  19  Programa               7680 non-null   object
#  20  Año PDL                7680 non-null   float64
#  21  Socios                 7680 non-null   object
# dtypes: float64(3), object(19)
# memory usage: 1.3+ MB

# %%
df
# Out:
#      Region_IE Provincia_IE           UGEL_IE   Distrito_IE  \
# 135   AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 136   AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 137   AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 138   AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 139   AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...        ...          ...               ...           ...
# 7849     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 7850     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 7851     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 7852     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 7853     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#          CentroPoblado_IE           Institucion_Educativa  CodigoLocal_IE  \
# 135              CHIRIACO  TECNICO INDUSTRIAL TUPAC AMARU          4772.0
# 136              CHIRIACO  TECNICO INDUSTRIAL TUPAC AMARU          4772.0
# 137              CHIRIACO  TECNICO INDUSTRIAL TUPAC AMARU          4772.0
# 138              CHIRIACO  TECNICO INDUSTRIAL TUPAC AMARU          4772.0
# 139              CHIRIACO  TECNICO INDUSTRIAL TUPAC AMARU          4772.0
# ...                   ...                             ...             ...
# 7849  SAN MIGUEL DE SEREN                           15192        416462.0
# 7850  SAN MIGUEL DE SEREN                           15192        416462.0
# 7851  SAN MIGUEL DE SEREN                           15192        416462.0
# 7852  SAN MIGUEL DE SEREN                           15192        416462.0
# 7853  SAN MIGUEL DE SEREN                           15192        416462.0
#
#       CodigoModular_IE     Grado           Fecha  ... % Positivas  \
# 135           593947.0  Sec-3ero  DICIEMBRE 2023  ...     64.29 %
# 136           593947.0  Sec-3ero  DICIEMBRE 2023  ...     76.79 %
# 137           593947.0  Sec-3ero  DICIEMBRE 2023  ...     76.19 %
# 138           593947.0  Sec-3ero  DICIEMBRE 2023  ...     36.73 %
# 139           593947.0  Sec-3ero  DICIEMBRE 2023  ...     48.57 %
# ...                ...       ...             ...  ...         ...
# 7849          350660.0  Pri-4rto      MARZO 2023  ...     60.00 %
# 7850          350660.0  Pri-4rto      MARZO 2023  ...     75.00 %
# 7851          350660.0  Pri-4rto      MARZO 2023  ...     76.67 %
# 7852          350660.0  Pri-4rto      MARZO 2023  ...     94.44 %
# 7853          350660.0  Pri-4rto      MARZO 2023  ...    100.00 %
#
#      Nivel de logro DNI_Participante ID_Participante  \
# 135      En proceso         72697925        0172d360
# 136   Satisfactorio         72697925        0172d360
# 137   Satisfactorio         72697925        0172d360
# 138      En proceso         72697925        0172d360
# 139      En proceso         72697925        0172d360
# ...             ...              ...             ...
# 7849     En proceso         76804501        b29b6c11
# 7850  Satisfactorio         76804501        b29b6c11
# 7851  Satisfactorio         76804501        b29b6c11
# 7852  Satisfactorio         76804501        b29b6c11
# 7853  Satisfactorio         76804501        b29b6c11
#
#                             Participante      Estatus  \
# 135   MIRANDA RAMIREZ, CLAUDIA VALENTINA  Activo Alto
# 136   MIRANDA RAMIREZ, CLAUDIA VALENTINA  Activo Alto
# 137   MIRANDA RAMIREZ, CLAUDIA VALENTINA  Activo Alto
# 138   MIRANDA RAMIREZ, CLAUDIA VALENTINA  Activo Alto
# 139   MIRANDA RAMIREZ, CLAUDIA VALENTINA  Activo Alto
# ...                                  ...          ...
# 7849           REMAYCUNA VASQUEZ, GLADYS  Activo Alto
# 7850           REMAYCUNA VASQUEZ, GLADYS  Activo Alto
# 7851           REMAYCUNA VASQUEZ, GLADYS  Activo Alto
# 7852           REMAYCUNA VASQUEZ, GLADYS  Activo Alto
# 7853           REMAYCUNA VASQUEZ, GLADYS  Activo Alto
#
#                         Coordinador/a Programa Año PDL  \
# 135         VELASQUEZ VALDES, DANIELA      PDL  2023.0
# 136         VELASQUEZ VALDES, DANIELA      PDL  2023.0
# 137         VELASQUEZ VALDES, DANIELA      PDL  2023.0
# 138         VELASQUEZ VALDES, DANIELA      PDL  2023.0
# 139         VELASQUEZ VALDES, DANIELA      PDL  2023.0
# ...                               ...      ...     ...
# 7849  VASQUEZ MONTERO, JAVIER ENRIQUE      PDL  2023.0
# 7850  VASQUEZ MONTERO, JAVIER ENRIQUE      PDL  2023.0
# 7851  VASQUEZ MONTERO, JAVIER ENRIQUE      PDL  2023.0
# 7852  VASQUEZ MONTERO, JAVIER ENRIQUE      PDL  2023.0
# 7853  VASQUEZ MONTERO, JAVIER ENRIQUE      PDL  2023.0
#
#                                 Socios
# 135                      Teach For All
# 136                      Teach For All
# 137                      Teach For All
# 138                      Teach For All
# 139                      Teach For All
# ...                                ...
# 7849  Fundación Albert Heijn - FLP/AHF
# 7850  Fundación Albert Heijn - FLP/AHF
# 7851  Fundación Albert Heijn - FLP/AHF
# 7852  Fundación Albert Heijn - FLP/AHF
# 7853  Fundación Albert Heijn - FLP/AHF
#
# [7680 rows x 22 columns]

# %%
# Contar la cantidad de estudiantes en cada nivel de logro
niveles_de_logro = df['Nivel de logro'].value_counts()

# Crear gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(niveles_de_logro.index, niveles_de_logro.values)
plt.title('Distribución de Estudiantes por Nivel de Logro', fontsize=14)
plt.xlabel('Nivel de Logro', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=0)
plt.show()

# %%
# Contar la cantidad de estudiantes en cada grado
distribucion_por_grado = df['Grado'].value_counts()

# Crear un orden específico para los grados
orden_grados = ['Pri-1ero', 'Pri-2ndo', 'Pri-3ero', 'Pri-4rto', 'Pri-5nto', 'Pri-6xto', 
                'Sec-1ero', 'Sec-2ndo', 'Sec-3ero', 'Sec-4rto', 'Sec-5nto']

# Reordenar los datos según el orden especificado
distribucion_por_grado = distribucion_por_grado.reindex(orden_grados)

# Crear gráfico de barras para la distribución por grado con el nuevo orden
plt.figure(figsize=(10, 6))
plt.bar(distribucion_por_grado.index, distribucion_por_grado.values) # , color='skyblue'
plt.title('Distribución de Estudiantes por Grado', fontsize=14)
plt.xlabel('Grado', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Crear una tabla que cuente los niveles de logro por región educativa
niveles_logro_por_region = df.groupby(['Region_IE', 'Nivel de logro']).size().unstack().fillna(0)

# Crear un gráfico de barras apiladas para comparar los niveles de logro entre regiones
niveles_logro_por_region.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.title('Comparación del Nivel de Logro entre Regiones Educativas', fontsize=14)
plt.xlabel('Región Educativa', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=90)
plt.legend(title='Nivel de Logro')
plt.show()

# %%
# Crear una tabla que cuente los niveles de logro por curso
niveles_logro_por_curso = df.groupby(['Programa', 'Nivel de logro']).size().unstack().fillna(0)

# Crear un gráfico de barras apiladas para comparar los niveles de logro entre cursos
niveles_logro_por_curso.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.title('Comparación del Nivel de Logro por Curso', fontsize=14)
plt.xlabel('Curso', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=0)
plt.legend(title='Nivel de Logro')
plt.show()
