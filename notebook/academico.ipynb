# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file = '../data/academico.csv'
df = pd.read_csv(file)
# Out:
# C:\Users\oscar\AppData\Local\Temp\ipykernel_15928\1986484111.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45222 entries, 0 to 45221
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              44582 non-null  object
#  1   Provincia_IE           44581 non-null  object
#  2   UGEL_IE                44581 non-null  object
#  3   Distrito_IE            44581 non-null  object
#  4   CentroPoblado_IE       44581 non-null  object
#  5   Institucion_Educativa  44581 non-null  object
#  6   CodigoLocal_IE         44581 non-null  float64
#  7   CodigoModular_IE       44581 non-null  float64
#  8   Estudiante             45065 non-null  object
#  9   Grado                  45220 non-null  object
#  10  Fecha                  45220 non-null  object
#  11  Curso                  45220 non-null  object
#  12  Competencia            45220 non-null  object
#  13  % Adecuadas            41064 non-null  object
# ...

# %%
df.describe()
# Out:
#        CodigoLocal_IE  CodigoModular_IE  Año PDL
# count    44581.000000      4.458100e+04  44581.0
# mean    198006.174155      5.606425e+05   2023.0
# std     163645.018045      3.731185e+05      0.0
# min        142.000000      2.171330e+05   2023.0
# 25%      25996.000000      3.289140e+05   2023.0
# 50%     178456.000000      4.207780e+05   2023.0
# 75%     314963.000000      6.226390e+05   2023.0
# max     823724.000000      1.794627e+06   2023.0

# %%
df = df.dropna()  # Elimina todas las filas con NaNs
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40316 entries, 651 to 45219
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              40316 non-null  object
#  1   Provincia_IE           40316 non-null  object
#  2   UGEL_IE                40316 non-null  object
#  3   Distrito_IE            40316 non-null  object
#  4   CentroPoblado_IE       40316 non-null  object
#  5   Institucion_Educativa  40316 non-null  object
#  6   CodigoLocal_IE         40316 non-null  float64
#  7   CodigoModular_IE       40316 non-null  float64
#  8   Estudiante             40316 non-null  object
#  9   Grado                  40316 non-null  object
#  10  Fecha                  40316 non-null  object
#  11  Curso                  40316 non-null  object
#  12  Competencia            40316 non-null  object
#  13  % Adecuadas            40316 non-null  object
# ...

# %%
df
# Out:
#       Region_IE Provincia_IE           UGEL_IE   Distrito_IE  \
# 651    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 653    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 654    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 655    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 656    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...         ...          ...               ...           ...
# 45215     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 45216     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 45217     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 45218     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 45219     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#           CentroPoblado_IE       Institucion_Educativa  CodigoLocal_IE  \
# 651                PAANTAM  16714 SUWIKAI TSAKIM MIYAN          4098.0
# 653                PAANTAM  16714 SUWIKAI TSAKIM MIYAN          4098.0
# ...

# %%
# Contar la cantidad de estudiantes en cada nivel de logro
niveles_de_logro = df['Nivel de logro'].value_counts()

# Crear gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(niveles_de_logro.index, niveles_de_logro.values)
plt.title('Distribución de Estudiantes por Nivel de Logro', fontsize=14)
plt.xlabel('Nivel de Logro', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Contar la cantidad de estudiantes en cada grado
distribucion_por_grado = df['Grado'].value_counts()

# Crear un orden específico para los grados
orden_grados = ['Pri-1ero', 'Pri-2ndo', 'Pri-3ero', 'Pri-4rto', 'Pri-5nto', 'Pri-6xto', 
                'Sec-1ero', 'Sec-2ndo', 'Sec-3ero', 'Sec-4rto', 'Sec-5nto']

# Reordenar los datos según el orden especificado
distribucion_por_grado = distribucion_por_grado.reindex(orden_grados)

# Crear gráfico de barras para la distribución por grado con el nuevo orden
plt.figure(figsize=(10, 6))
plt.bar(distribucion_por_grado.index, distribucion_por_grado.values) # , color='skyblue'
plt.title('Distribución de Estudiantes por Grado', fontsize=14)
plt.xlabel('Grado', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Contar la cantidad de estudiantes en cada grado
distribucion_por_grado = df.groupby(['Grado', 'Nivel de logro']).size().unstack().fillna(0)

# Crear un orden específico para los grados
orden_grados = ['Pri-1ero', 'Pri-2ndo', 'Pri-3ero', 'Pri-4rto', 'Pri-5nto', 'Pri-6xto', 
                'Sec-1ero', 'Sec-2ndo', 'Sec-3ero', 'Sec-4rto', 'Sec-5nto']

# Reordenar los datos según el orden especificado
distribucion_por_grado = distribucion_por_grado.reindex(orden_grados)

# Crear gráfico de barras para la distribución por grado con el nuevo orden
plt.figure(figsize=(10, 6))
plt.bar(distribucion_por_grado.index, distribucion_por_grado.values) # , color='skyblue'
plt.title('Distribución de Estudiantes por Grado', fontsize=14)
plt.xlabel('Grado', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# # Crear una tabla que cuente los niveles de logro por región educativa
# niveles_logro_por_region = df.groupby(['Region_IE', 'Nivel de logro']).size().unstack().fillna(0)

# # Crear un gráfico de barras apiladas para comparar los niveles de logro entre regiones
# niveles_logro_por_region.plot(kind='bar', stacked=True, figsize=(14, 8))
# plt.title('Comparación del Nivel de Logro entre Regiones Educativas', fontsize=14)
# plt.xlabel('Región Educativa', fontsize=12)
# plt.ylabel('Cantidad de Estudiantes', fontsize=12)
# plt.xticks(rotation=90)
# plt.legend(title='Nivel de Logro')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      11 # Crear gráfico de barras para la distribución por grado con el nuevo orden
#      12 plt.figure(figsize=(10, 6))
# ---> 13 plt.bar(distribucion_por_grado.index, distribucion_por_grado.values) # , color='skyblue'
#      14 plt.title('Distribución de Estudiantes por Grado', fontsize=14)
#      15 plt.xlabel('Grado', fontsize=12)
#
# File c:\Users\oscar\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
# ...

# %%
# Crear una tabla que cuente los niveles de logro por región educativa
niveles_logro_por_region = df.groupby(['Region_IE', 'Nivel de logro']).size().unstack().fillna(0)

# Crear un gráfico de barras apiladas para comparar los niveles de logro entre regiones
niveles_logro_por_region.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.title('Comparación del Nivel de Logro entre Regiones Educativas', fontsize=14)
plt.xlabel('Región Educativa', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=90)
plt.legend(title='Nivel de Logro')
plt.show()

# %%
# Crear una tabla que cuente los niveles de logro por curso
niveles_logro_por_curso = df.groupby(['Curso', 'Nivel de logro']).size().unstack().fillna(0)

# Crear un gráfico de barras apiladas para comparar los niveles de logro entre cursos
niveles_logro_por_curso.plot(kind='bar', stacked=True, figsize=(14, 8))
plt.title('Comparación del Nivel de Logro por Curso', fontsize=14)
plt.xlabel('Curso', fontsize=12)
plt.ylabel('Cantidad de Estudiantes', fontsize=12)
plt.xticks(rotation=0)
plt.legend(title='Nivel de Logro')
plt.show()

# %%
niveles_logro_por_curso
# 0.3892357206560937
# 0.4735635112753217
# Out:
# Nivel de logro  En inicio  En proceso  Satisfactorio
# Curso
# COMUNICACIÓN          798        3334           3717
# CTA                   382        1193            849
# INGLÉS                313         923           3018
# MATEMÁTICA           6216        9535          10038
