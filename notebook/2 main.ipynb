# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Lectura de Datasets

# %% [markdown]
# ### Academico Dataset

# %%
dataset = 'academico'
file = f'../data/{dataset}.csv'
df_academico = pd.read_csv(file)
# Out:
# C:\Users\jange\AppData\Local\Temp\ipykernel_824\1230527439.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_academico = pd.read_csv(file)

# %%
df_academico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45222 entries, 0 to 45221
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              44582 non-null  object
#  1   Provincia_IE           44581 non-null  object
#  2   UGEL_IE                44581 non-null  object
#  3   Distrito_IE            44581 non-null  object
#  4   CentroPoblado_IE       44581 non-null  object
#  5   Institucion_Educativa  44581 non-null  object
#  6   CodigoLocal_IE         44581 non-null  float64
#  7   CodigoModular_IE       44581 non-null  float64
#  8   Estudiante             45065 non-null  object
#  9   Grado                  45220 non-null  object
#  10  Fecha                  45220 non-null  object
#  11  Curso                  45220 non-null  object
#  12  Competencia            45220 non-null  object
#  13  % Adecuadas            41064 non-null  object
#  14  Nivel de logro         45220 non-null  object
#  15  DNI_Participante       44517 non-null  object
#  16  ID_Participante        44581 non-null  object
#  17  Participante           44581 non-null  object
#  18  Estatus                44581 non-null  object
#  19  Coordinador/a          44581 non-null  object
#  20  Programa               44581 non-null  object
#  21  Año PDL                44581 non-null  float64
#  22  Socios                 44581 non-null  object
# dtypes: float64(3), object(20)
# memory usage: 7.9+ MB

# %%
df_academico_columns = df_academico.columns
df_academico_columns
# Out:
# Index(['Region_IE', 'Provincia_IE', 'UGEL_IE', 'Distrito_IE',
#        'CentroPoblado_IE', 'Institucion_Educativa', 'CodigoLocal_IE',
#        'CodigoModular_IE', 'Estudiante', 'Grado', 'Fecha', 'Curso',
#        'Competencia', '% Adecuadas', 'Nivel de logro', 'DNI_Participante',
#        'ID_Participante', 'Participante', 'Estatus', 'Coordinador/a',
#        'Programa', 'Año PDL', 'Socios'],
#       dtype='object')

# %%
df_academico_ID_Participante = df_academico['ID_Participante'].unique()
print(len(df_academico_ID_Participante))
# Out:
# 232

# %% [markdown]
# ### Clima de Aula Dataset

# %%
dataset = 'clima_aula'
file = f'../data/{dataset}.csv'
df_clima_aula = pd.read_csv(file)

# %%
df_clima_aula.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7856 entries, 0 to 7855
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              7720 non-null   object
#  1   Provincia_IE           7719 non-null   object
#  2   UGEL_IE                7719 non-null   object
#  3   Distrito_IE            7719 non-null   object
#  4   CentroPoblado_IE       7719 non-null   object
#  5   Institucion_Educativa  7719 non-null   object
#  6   CodigoLocal_IE         7719 non-null   float64
#  7   CodigoModular_IE       7719 non-null   float64
#  8   Grado                  7854 non-null   object
#  9   Fecha                  7854 non-null   object
#  10  Evaluacion             7854 non-null   object
#  11  Elemento               7854 non-null   object
#  12  % Positivas            7829 non-null   object
#  13  Nivel de logro         7854 non-null   object
#  14  DNI_Participante       7705 non-null   object
#  15  ID_Participante        7719 non-null   object
#  16  Participante           7719 non-null   object
#  17  Estatus                7719 non-null   object
#  18  Coordinador/a          7719 non-null   object
#  19  Programa               7719 non-null   object
#  20  Año PDL                7719 non-null   float64
#  21  Socios                 7719 non-null   object
# dtypes: float64(3), object(19)
# memory usage: 1.3+ MB

# %%
df_clima_aula_columns = df_clima_aula.columns
df_clima_aula_columns
# Out:
# Index(['Region_IE', 'Provincia_IE', 'UGEL_IE', 'Distrito_IE',
#        'CentroPoblado_IE', 'Institucion_Educativa', 'CodigoLocal_IE',
#        'CodigoModular_IE', 'Grado', 'Fecha', 'Evaluacion', 'Elemento',
#        '% Positivas', 'Nivel de logro', 'DNI_Participante', 'ID_Participante',
#        'Participante', 'Estatus', 'Coordinador/a', 'Programa', 'Año PDL',
#        'Socios'],
#       dtype='object')

# %%
df_clima_aula_ID_Participante = df_clima_aula['ID_Participante'].unique()
print(len(df_clima_aula_ID_Participante))
# Out:
# 259

# %% [markdown]
# ### Socio-emocional Dataset

# %%
dataset = 'socioemocional'
file = f'../data/{dataset}.csv'
df_socioemocional = pd.read_csv(file)
# Out:
# C:\Users\jange\AppData\Local\Temp\ipykernel_824\3496925767.py:3: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_socioemocional = pd.read_csv(file)

# %%
df_socioemocional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150003 entries, 0 to 150002
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Region_IE              144732 non-null  object
#  1   Provincia_IE           144730 non-null  object
#  2   UGEL_IE                144730 non-null  object
#  3   Distrito_IE            144730 non-null  object
#  4   CentroPoblado_IE       144730 non-null  object
#  5   Institucion_Educativa  144730 non-null  object
#  6   CodigoLocal_IE         144730 non-null  float64
#  7   CodigoModular_IE       144730 non-null  float64
#  8   Estudiante             149593 non-null  object
#  9   Grado                  150000 non-null  object
#  10  Fecha                  150000 non-null  object
#  11  Evaluación             150000 non-null  object
#  12  Habilidad              150000 non-null  object
#  13  Promedio               150000 non-null  float64
#  14  Nivel de logro         150000 non-null  object
#  15  DNI_Participante       144692 non-null  object
#  16  ID_Participante        144730 non-null  object
#  17  Participante           144730 non-null  object
#  18  Estatus                144730 non-null  object
#  19  Coordinador/a          144730 non-null  object
#  20  Programa               144730 non-null  object
#  21  Año PDL                144730 non-null  float64
#  22  Socios                 144730 non-null  object
# dtypes: float64(4), object(19)
# memory usage: 26.3+ MB

# %%
df_socioemocional_columns = df_socioemocional.columns
df_socioemocional_columns
# Out:
# Index(['Region_IE', 'Provincia_IE', 'UGEL_IE', 'Distrito_IE',
#        'CentroPoblado_IE', 'Institucion_Educativa', 'CodigoLocal_IE',
#        'CodigoModular_IE', 'Estudiante', 'Grado', 'Fecha', 'Evaluación',
#        'Habilidad', 'Promedio', 'Nivel de logro', 'DNI_Participante',
#        'ID_Participante', 'Participante', 'Estatus', 'Coordinador/a',
#        'Programa', 'Año PDL', 'Socios'],
#       dtype='object')

# %%
df_socioemocional_ID_Participante = df_socioemocional['ID_Participante'].unique()
print(len(df_socioemocional_ID_Participante))
# Out:
# 181

# %% [markdown]
# ## Agrupamiento y Transformación de Datos

# %% [markdown]
# ACADEMICO - Eliminar registros con valores nulos en esos 3 Primary keys

# %%
columns_to_check = ["CodigoModular_IE", "Grado", "ID_Participante"]
cleaned_df_aca = df_academico.dropna(subset=columns_to_check)
cleaned_df_aca.ID_Participante.nunique()
# Out:
# 231

# %% [markdown]
# ACADEMICO - Agrupar por las siguientes columnas y tomar la moda de la variable `Nivel de logro`

# %%
group_cols = ['Region_IE', 'Provincia_IE', 'UGEL_IE', 'Distrito_IE',
       'CentroPoblado_IE','CodigoLocal_IE',
       'CodigoModular_IE', 'Grado', 'Fecha','ID_Participante']

# %%
result_aca = cleaned_df_aca.groupby(group_cols)["Nivel de logro"].agg(lambda x: x.mode().iloc[0] if not x.mode().empty else None).reset_index()
result_aca
# Out:
#     Region_IE Provincia_IE           UGEL_IE   Distrito_IE  \
# 0    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4    AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ..        ...          ...               ...           ...
# 873     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 874     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 875     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 876     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 877     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#         CentroPoblado_IE  CodigoLocal_IE  CodigoModular_IE     Grado  \
# 0                PAANTAM          4098.0          926535.0  Sec-3ero
# 1                PAANTAM          4098.0          926535.0  Sec-3ero
# 2                PAANTAM          4098.0          926535.0  Sec-3ero
# 3                PAANTAM          4098.0          926535.0  Sec-3ero
# 4                PAANTAM          4098.0          926535.0  Sec-3ero
# ..                   ...             ...               ...       ...
# 873  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-1ero
# 874  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-1ero
# 875  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-4rto
# 876  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-4rto
# 877  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-4rto
#
#               Fecha ID_Participante Nivel de logro
# 0    DICIEMBRE 2023        0172b7cf  Satisfactorio
# 1    DICIEMBRE 2023        b29b27c1      En inicio
# 2        JULIO 2023        0172b7cf  Satisfactorio
# 3        JULIO 2023        b29b27c1     En proceso
# 4        MARZO 2023        0172b7cf     En proceso
# ..              ...             ...            ...
# 873      JULIO 2023        b29b2e71  Satisfactorio
# 874      MARZO 2023        b29b2e71      En inicio
# 875  DICIEMBRE 2023        b29b6c11     En proceso
# 876      JULIO 2023        b29b6c11      En inicio
# 877      MARZO 2023        b29b6c11      En inicio
#
# [878 rows x 11 columns]

# %% [markdown]
# SOCIOEMOCIONAL - Eliminar registros con valores nulos en esos 3 Primary keys

# %%
columns_to_check = ["CodigoModular_IE", "Grado", "ID_Participante"]
cleaned_df_soc = df_socioemocional.dropna(subset=columns_to_check)
cleaned_df_soc.ID_Participante.nunique()
# Out:
# 180

# %%
cleaned_df_soc[cleaned_df_soc.Fecha == "MARZO 2023"].Habilidad.value_counts()
# Out:
# Habilidad
# Autocuidado                                       3223
# Autoestima                                        3058
# Conciencia emocional                              2492
# Comunicación asertiva                             2242
# Trabajo en equipo                                 2241
# Toma de decisiones responsables                   2240
# Regulación emocional                              2238
# Resolución de conflictos                          2237
# Conciencia social                                 2236
# Empatía                                           2233
# Comportamiento prosocial                          2233
# Autoconcepto                                      2192
# Limitados recursos económicos                     1478
# Limitada expectativa sobre la educación           1477
# Violencia escolar                                 1476
# Violencia familiar                                1476
# Consumo de alcohol y drogas                       1475
# Desinformación sobre educación sexual integral    1475
# Ausentismo y deserción escolar                    1474
# Creatividad                                       1474
# Entorno de riesgo                                 1474
# Trabajo adolescente                               1473
# Violencia de género                                808
# Limitada expectativa sobre su proyecto de vida     805
# Percepción sobre estereotipos de género            669
# Name: count, dtype: int64

# %% [markdown]
# SOCIOEMOCIONAL - Agrupar por las columnas anteriores, transformar por Habilidad y tomar la moda de la variable `Nivel de logro` por cada Habilidad

# %%
result = cleaned_df_soc.pivot_table(
    index=group_cols,
    columns="Habilidad",
    values="Nivel de logro",
    aggfunc=lambda x: x.mode().iloc[0] if not x.mode().empty else None
).reset_index()

# %%
result.columns.name = None
result = result.rename_axis(None, axis=1)
result
# Out:
#     Region_IE Provincia_IE          UGEL_IE  Distrito_IE CentroPoblado_IE  \
# 0    AMAZONAS        BAGUA  UGEL IBIR-IMAZA        IMAZA         CHIRIACO
# 1    AMAZONAS        BAGUA  UGEL IBIR-IMAZA        IMAZA         CHIRIACO
# 2    AMAZONAS        BAGUA  UGEL IBIR-IMAZA        IMAZA         CHIRIACO
# 3    AMAZONAS        BAGUA  UGEL IBIR-IMAZA        IMAZA         CHIRIACO
# 4    AMAZONAS        BAGUA  UGEL IBIR-IMAZA        IMAZA         CHIRIACO
# ..        ...          ...              ...          ...              ...
# 725       ICA          ICA         UGEL ICA  LOS AQUIJES       EL ROSARIO
# 726       ICA          ICA         UGEL ICA  LOS AQUIJES       EL ROSARIO
# 727       ICA          ICA         UGEL ICA  LOS AQUIJES       EL ROSARIO
# 728       ICA          ICA         UGEL ICA  LOS AQUIJES       EL ROSARIO
# 729       ICA          ICA         UGEL ICA  LOS AQUIJES       EL ROSARIO
#
#      CodigoLocal_IE  CodigoModular_IE     Grado           Fecha  \
# 0            4772.0          593947.0  Sec-1ero  DICIEMBRE 2023
# 1            4772.0          593947.0  Sec-1ero      JULIO 2023
# 2            4772.0          593947.0  Sec-1ero      MARZO 2023
# 3            4772.0          593947.0  Sec-3ero  DICIEMBRE 2023
# 4            4772.0          593947.0  Sec-3ero  DICIEMBRE 2023
# ..              ...               ...       ...             ...
# 725        212200.0          277616.0  Pri-3ero      JULIO 2023
# 726        212200.0          277616.0  Pri-3ero      MARZO 2023
# 727        212200.0          277616.0  Pri-5nto  DICIEMBRE 2023
# 728        212200.0          277616.0  Pri-5nto      JULIO 2023
# 729        212200.0          277616.0  Pri-5nto      MARZO 2023
#
#     ID_Participante  ... Limitados recursos económicos  \
# 0          b29b6a82  ...                    En proceso
# 1          b29b6a82  ...                    En proceso
# 2          b29b6a82  ...                    En proceso
# 3          0172d360  ...                    En proceso
# 4          b29b6a82  ...                    En proceso
# ..              ...  ...                           ...
# 725        95b7a15c  ...                           NaN
# 726        95b7a15c  ...                           NaN
# 727        95b96748  ...                           NaN
# 728        95b96748  ...                           NaN
# 729        95b96748  ...                           NaN
#
#     Percepción sobre estereotipos de género Regulación emocional  \
# 0                                En proceso        Satisfactorio
# 1                                En proceso        Satisfactorio
# 2                                En proceso        Satisfactorio
# 3                                       NaN           En proceso
# 4                                       NaN        Satisfactorio
# ..                                      ...                  ...
# 725                                     NaN                  NaN
# 726                                     NaN                  NaN
# 727                                     NaN        Satisfactorio
# 728                                     NaN        Satisfactorio
# 729                                     NaN        Satisfactorio
#
#     Resolución de conflictos Toma de decisiones responsables  \
# 0              Satisfactorio                   Satisfactorio
# 1              Satisfactorio                   Satisfactorio
# 2              Satisfactorio                   Satisfactorio
# 3                 En proceso                   Satisfactorio
# 4                 En proceso                   Satisfactorio
# ..                       ...                             ...
# 725                      NaN                             NaN
# 726                      NaN                             NaN
# 727            Satisfactorio                   Satisfactorio
# 728            Satisfactorio                      En proceso
# 729            Satisfactorio                   Satisfactorio
#
#     Trabajo adolescente Trabajo en equipo Violencia de género  \
# 0            En proceso     Satisfactorio                 NaN
# 1            En proceso     Satisfactorio                 NaN
# 2            En proceso     Satisfactorio                 NaN
# 3            En proceso     Satisfactorio          En proceso
# 4            En proceso     Satisfactorio          En proceso
# ..                  ...               ...                 ...
# 725                 NaN               NaN                 NaN
# 726                 NaN               NaN                 NaN
# 727                 NaN        En proceso                 NaN
# 728                 NaN        En proceso                 NaN
# 729                 NaN        En proceso                 NaN
#
#     Violencia escolar Violencia familiar
# 0          En proceso         En proceso
# 1          En proceso         En proceso
# 2          En proceso         En proceso
# 3          En proceso         En proceso
# 4          En proceso         En proceso
# ..                ...                ...
# 725               NaN                NaN
# 726               NaN                NaN
# 727               NaN                NaN
# 728               NaN                NaN
# 729               NaN                NaN
#
# [730 rows x 35 columns]

# %% [markdown]
# CLIMA DE AULA - Eliminar registros con valores nulos en esos 3 Primary keys

# %%
columns_to_check = ["CodigoModular_IE", "Grado", "ID_Participante"]
cleaned_df_cli = df_clima_aula.dropna(subset=columns_to_check)
cleaned_df_cli.ID_Participante.nunique()
# Out:
# 258

# %%
cleaned_df_cli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7719 entries, 135 to 7853
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Region_IE              7719 non-null   object
#  1   Provincia_IE           7719 non-null   object
#  2   UGEL_IE                7719 non-null   object
#  3   Distrito_IE            7719 non-null   object
#  4   CentroPoblado_IE       7719 non-null   object
#  5   Institucion_Educativa  7719 non-null   object
#  6   CodigoLocal_IE         7719 non-null   float64
#  7   CodigoModular_IE       7719 non-null   float64
#  8   Grado                  7719 non-null   object
#  9   Fecha                  7719 non-null   object
#  10  Evaluacion             7719 non-null   object
#  11  Elemento               7719 non-null   object
#  12  % Positivas            7694 non-null   object
#  13  Nivel de logro         7719 non-null   object
#  14  DNI_Participante       7705 non-null   object
#  15  ID_Participante        7719 non-null   object
#  16  Participante           7719 non-null   object
#  17  Estatus                7719 non-null   object
#  18  Coordinador/a          7719 non-null   object
#  19  Programa               7719 non-null   object
#  20  Año PDL                7719 non-null   float64
#  21  Socios                 7719 non-null   object
# dtypes: float64(3), object(19)
# memory usage: 1.4+ MB

# %% [markdown]
# CLIMA DE AULA - Agrupar por las columnas anteriores, transformar por Elemento y tomar la moda de la variable `Nivel de logro` por cada Elemento

# %%
result_cli = cleaned_df_cli.pivot_table(
    index=group_cols,
    columns="Elemento",
    values="Nivel de logro",
    aggfunc=lambda x: x.mode().iloc[0] if not x.mode().empty else None
).reset_index()

# %%
result_cli.columns.name = None
result_cli = result_cli.rename_axis(None, axis=1)
result_cli
# Out:
#      Region_IE Provincia_IE           UGEL_IE   Distrito_IE  \
# 0     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...        ...          ...               ...           ...
# 1054     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1055     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1056     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1057     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1058     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#          CentroPoblado_IE  CodigoLocal_IE  CodigoModular_IE     Grado  \
# 0                CHIRIACO          4772.0          593947.0  Sec-1ero
# 1                CHIRIACO          4772.0          593947.0  Sec-1ero
# 2                CHIRIACO          4772.0          593947.0  Sec-1ero
# 3                CHIRIACO          4772.0          593947.0  Sec-3ero
# 4                CHIRIACO          4772.0          593947.0  Sec-3ero
# ...                   ...             ...               ...       ...
# 1054  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-1ero
# 1055  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-1ero
# 1056  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-1ero
# 1057  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-4rto
# 1058  SAN MIGUEL DE SEREN        416462.0          350660.0  Pri-4rto
#
#                Fecha ID_Participante Aprendizaje completamente interiorizado  \
# 0     DICIEMBRE 2023        b29b6a82                           Satisfactorio
# 1         JULIO 2023        b29b6a82                              En proceso
# 2         MARZO 2023        b29b6a82                           Satisfactorio
# 3     DICIEMBRE 2023        0172d360                              En proceso
# 4     DICIEMBRE 2023        b29b6a82                              En proceso
# ...              ...             ...                                     ...
# 1054  DICIEMBRE 2023        b29b2e71                           Satisfactorio
# 1055      JULIO 2023        b29b2e71                           Satisfactorio
# 1056      MARZO 2023        b29b2e71                           Satisfactorio
# 1057      JULIO 2023        b29b6c11                           Satisfactorio
# 1058      MARZO 2023        b29b6c11                           Satisfactorio
#
#      Comprensión comprobada y asegurada Expectativas rigurosas mantenidas  \
# 0                         Satisfactorio                     Satisfactorio
# 1                            En proceso                     Satisfactorio
# 2                         Satisfactorio                        En proceso
# 3                         Satisfactorio                     Satisfactorio
# 4                         Satisfactorio                     Satisfactorio
# ...                                 ...                               ...
# 1054                      Satisfactorio                     Satisfactorio
# 1055                      Satisfactorio                     Satisfactorio
# 1056                      Satisfactorio                     Satisfactorio
# 1057                      Satisfactorio                     Satisfactorio
# 1058                      Satisfactorio                        En proceso
#
#      Se crea una cultura positiva y un entorno de aprendizaje.  \
# 0                                             En inicio
# 1                                             En inicio
# 2                                             En inicio
# 3                                            En proceso
# 4                                             En inicio
# ...                                                 ...
# 1054                                      Satisfactorio
# 1055                                      Satisfactorio
# 1056                                      Satisfactorio
# 1057                                      Satisfactorio
# 1058                                      Satisfactorio
#
#      Se establece un entorno de aprendizaje atractivo  \
# 0                                          En proceso
# 1                                          En proceso
# 2                                          En proceso
# 3                                          En proceso
# 4                                          En proceso
# ...                                               ...
# 1054                                    Satisfactorio
# 1055                                    Satisfactorio
# 1056                                    Satisfactorio
# 1057                                    Satisfactorio
# 1058                                    Satisfactorio
#
#      Se fomentan relaciones alentadoras y de apoyo.  \
# 0                                        En proceso
# 1                                        En proceso
# 2                                        En proceso
# 3                                     Satisfactorio
# 4                                        En proceso
# ...                                             ...
# 1054                                  Satisfactorio
# 1055                                  Satisfactorio
# 1056                                  Satisfactorio
# 1057                                  Satisfactorio
# 1058                                  Satisfactorio
#
#      Se valoran los aportes y las ideas de los estudiantes
# 0                                            En proceso
# 1                                            En proceso
# 2                                            En proceso
# 3                                         Satisfactorio
# 4                                         Satisfactorio
# ...                                                 ...
# 1054                                      Satisfactorio
# 1055                                      Satisfactorio
# 1056                                      Satisfactorio
# 1057                                      Satisfactorio
# 1058                                      Satisfactorio
#
# [1059 rows x 17 columns]

# %% [markdown]
# ## Cruce de Tablas
#
# Cruce por "CodigoModular_IE", "Grado", "ID_Participante" y "Fecha"

# %%
merged_df = result_aca.merge(result, on=["CodigoModular_IE", "Grado", "ID_Participante","Fecha"], how="inner")
merged_df = merged_df.merge(result_cli, on=["CodigoModular_IE", "Grado", "ID_Participante","Fecha"], how="inner")
merged_df
# Out:
#     Region_IE_x Provincia_IE_x        UGEL_IE_x Distrito_IE_x  \
# 0      AMAZONAS          BAGUA  UGEL IBIR-IMAZA         IMAZA
# 1      AMAZONAS          BAGUA  UGEL IBIR-IMAZA         IMAZA
# 2      AMAZONAS          BAGUA  UGEL IBIR-IMAZA         IMAZA
# 3      AMAZONAS          BAGUA  UGEL IBIR-IMAZA         IMAZA
# 4      AMAZONAS          BAGUA  UGEL IBIR-IMAZA         IMAZA
# ..          ...            ...              ...           ...
# 573         ICA            ICA         UGEL ICA   LOS AQUIJES
# 574         ICA            ICA         UGEL ICA   LOS AQUIJES
# 575         ICA            ICA         UGEL ICA   LOS AQUIJES
# 576         ICA            ICA         UGEL ICA   LOS AQUIJES
# 577         ICA            ICA         UGEL ICA   LOS AQUIJES
#
#     CentroPoblado_IE_x  CodigoLocal_IE_x  CodigoModular_IE     Grado  \
# 0              PAANTAM            4098.0          926535.0  Sec-3ero
# 1              PAANTAM            4098.0          926535.0  Sec-3ero
# 2              PAANTAM            4098.0          926535.0  Sec-3ero
# 3              PAANTAM            4098.0          926535.0  Sec-3ero
# 4              PAANTAM            4098.0          926535.0  Sec-3ero
# ..                 ...               ...               ...       ...
# 573         EL ROSARIO          212200.0          277616.0  Pri-3ero
# 574         EL ROSARIO          212200.0          277616.0  Pri-3ero
# 575         EL ROSARIO          212200.0          277616.0  Pri-5nto
# 576         EL ROSARIO          212200.0          277616.0  Pri-5nto
# 577         EL ROSARIO          212200.0          277616.0  Pri-5nto
#
#               Fecha ID_Participante  ...  Distrito_IE CentroPoblado_IE  \
# 0    DICIEMBRE 2023        0172b7cf  ...        IMAZA          PAANTAM
# 1    DICIEMBRE 2023        b29b27c1  ...        IMAZA          PAANTAM
# 2        JULIO 2023        0172b7cf  ...        IMAZA          PAANTAM
# 3        JULIO 2023        b29b27c1  ...        IMAZA          PAANTAM
# 4        MARZO 2023        0172b7cf  ...        IMAZA          PAANTAM
# ..              ...             ...  ...          ...              ...
# 573      JULIO 2023        95b7a15c  ...  LOS AQUIJES       EL ROSARIO
# 574      MARZO 2023        95b7a15c  ...  LOS AQUIJES       EL ROSARIO
# 575  DICIEMBRE 2023        95b96748  ...  LOS AQUIJES       EL ROSARIO
# 576      JULIO 2023        95b96748  ...  LOS AQUIJES       EL ROSARIO
# 577      MARZO 2023        95b96748  ...  LOS AQUIJES       EL ROSARIO
#
#     CodigoLocal_IE Aprendizaje completamente interiorizado  \
# 0           4098.0                           Satisfactorio
# 1           4098.0                              En proceso
# 2           4098.0                           Satisfactorio
# 3           4098.0                              En proceso
# 4           4098.0                           Satisfactorio
# ..             ...                                     ...
# 573       212200.0                           Satisfactorio
# 574       212200.0                              En proceso
# 575       212200.0                           Satisfactorio
# 576       212200.0                           Satisfactorio
# 577       212200.0                              En proceso
#
#     Comprensión comprobada y asegurada Expectativas rigurosas mantenidas  \
# 0                        Satisfactorio                     Satisfactorio
# 1                           En proceso                        En proceso
# 2                        Satisfactorio                     Satisfactorio
# 3                           En proceso                         En inicio
# 4                        Satisfactorio                     Satisfactorio
# ..                                 ...                               ...
# 573                      Satisfactorio                     Satisfactorio
# 574                      Satisfactorio                        En proceso
# 575                      Satisfactorio                        En proceso
# 576                      Satisfactorio                        En proceso
# 577                      Satisfactorio                        En proceso
#
#      Se crea una cultura positiva y un entorno de aprendizaje.  \
# 0                                           En proceso
# 1                                           En proceso
# 2                                        Satisfactorio
# 3                                            En inicio
# 4                                            En inicio
# ..                                                 ...
# 573                                      Satisfactorio
# 574                                         En proceso
# 575                                         En proceso
# 576                                         En proceso
# 577                                         En proceso
#
#     Se establece un entorno de aprendizaje atractivo  \
# 0                                         En proceso
# 1                                         En proceso
# 2                                         En proceso
# 3                                         En proceso
# 4                                         En proceso
# ..                                               ...
# 573                                    Satisfactorio
# 574                                    Satisfactorio
# 575                                    Satisfactorio
# 576                                    Satisfactorio
# 577                                    Satisfactorio
#
#     Se fomentan relaciones alentadoras y de apoyo.  \
# 0                                    Satisfactorio
# 1                                       En proceso
# 2                                    Satisfactorio
# 3                                        En inicio
# 4                                    Satisfactorio
# ..                                             ...
# 573                                  Satisfactorio
# 574                                     En proceso
# 575                                  Satisfactorio
# 576                                  Satisfactorio
# 577                                  Satisfactorio
#
#     Se valoran los aportes y las ideas de los estudiantes
# 0                                        Satisfactorio
# 1                                           En proceso
# 2                                        Satisfactorio
# 3                                           En proceso
# 4                                        Satisfactorio
# ..                                                 ...
# 573                                      Satisfactorio
# 574                                         En proceso
# 575                                      Satisfactorio
# 576                                      Satisfactorio
# 577                                      Satisfactorio
#
# [578 rows x 55 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 55 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Region_IE_x                                                578 non-null    object
#  1   Provincia_IE_x                                             578 non-null    object
#  2   UGEL_IE_x                                                  578 non-null    object
#  3   Distrito_IE_x                                              578 non-null    object
#  4   CentroPoblado_IE_x                                         578 non-null    object
#  5   CodigoLocal_IE_x                                           578 non-null    float64
#  6   CodigoModular_IE                                           578 non-null    float64
#  7   Grado                                                      578 non-null    object
#  8   Fecha                                                      578 non-null    object
#  9   ID_Participante                                            578 non-null    object
#  10  Nivel de logro                                             578 non-null    object
#  11  Region_IE_y                                                578 non-null    object
#  12  Provincia_IE_y                                             578 non-null    object
#  13  UGEL_IE_y                                                  578 non-null    object
#  14  Distrito_IE_y                                              578 non-null    object
#  15  CentroPoblado_IE_y                                         578 non-null    object
#  16  CodigoLocal_IE_y                                           578 non-null    float64
#  17  Ausentismo y deserción escolar                             190 non-null    object
#  18  Autoconcepto                                               351 non-null    object
#  19  Autocuidado                                                578 non-null    object
#  20  Autoestima                                                 568 non-null    object
#  21  Comportamiento prosocial                                   351 non-null    object
#  22  Comunicación asertiva                                      351 non-null    object
#  23  Conciencia emocional                                       417 non-null    object
#  24  Conciencia social                                          351 non-null    object
#  25  Consumo de alcohol y drogas                                190 non-null    object
#  26  Creatividad                                                190 non-null    object
#  27  Desinformación sobre educación sexual integral             190 non-null    object
#  28  Empatía                                                    351 non-null    object
#  29  Entorno de riesgo                                          190 non-null    object
#  30  Limitada expectativa sobre la educación                    190 non-null    object
#  31  Limitada expectativa sobre su proyecto de vida             89 non-null     object
#  32  Limitados recursos económicos                              190 non-null    object
#  33  Percepción sobre estereotipos de género                    101 non-null    object
#  34  Regulación emocional                                       351 non-null    object
#  35  Resolución de conflictos                                   351 non-null    object
#  36  Toma de decisiones responsables                            351 non-null    object
#  37  Trabajo adolescente                                        190 non-null    object
#  38  Trabajo en equipo                                          351 non-null    object
#  39  Violencia de género                                        89 non-null     object
#  40  Violencia escolar                                          190 non-null    object
#  41  Violencia familiar                                         190 non-null    object
#  42  Region_IE                                                  578 non-null    object
#  43  Provincia_IE                                               578 non-null    object
#  44  UGEL_IE                                                    578 non-null    object
#  45  Distrito_IE                                                578 non-null    object
#  46  CentroPoblado_IE                                           578 non-null    object
#  47  CodigoLocal_IE                                             578 non-null    float64
#  48  Aprendizaje completamente interiorizado                    578 non-null    object
#  49  Comprensión comprobada y asegurada                         578 non-null    object
#  50  Expectativas rigurosas mantenidas                          578 non-null    object
#  51  Se crea una cultura positiva y un entorno de aprendizaje.  578 non-null    object
#  52  Se establece un entorno de aprendizaje atractivo           578 non-null    object
#  53  Se fomentan relaciones alentadoras y de apoyo.             578 non-null    object
#  54  Se valoran los aportes y las ideas de los estudiantes      578 non-null    object
# dtypes: float64(4), object(51)
# memory usage: 248.5+ KB

# %%
merged_df.ID_Participante.nunique()
# Out:
# 157
