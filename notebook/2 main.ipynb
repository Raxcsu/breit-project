# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.inspection import permutation_importance
#import shap

# %% [markdown]
# ## Lectura de Datasets

# %% [markdown]
# ### Academico Dataset

# %%
dataset = 'academico_'
file = f'../data/{dataset}.csv'
df_academico = pd.read_csv(file)
# Out:
# C:\Users\jange\AppData\Local\Temp\ipykernel_95044\3250444663.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_academico = pd.read_csv(file)

# %%
df_academico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93063 entries, 0 to 93062
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AÑO                    93063 non-null  int64
#  1   region_ie              93063 non-null  object
#  2   provincia_ie           93063 non-null  object
#  3   ugel_ie                93063 non-null  object
#  4   distrito_ie            93063 non-null  object
#  5   centropoblado_ie       93063 non-null  object
#  6   institucion_educativa  93063 non-null  object
#  7   codigolocal_ie         93063 non-null  int64
#  8   codigomodular_ie       93063 non-null  int64
#  9   ruralidad              93063 non-null  object
#  10  estudiantes            93063 non-null  object
#  11  grado                  93063 non-null  object
#  12  periodo                93063 non-null  object
#  13  curso                  93063 non-null  object
#  14  comp                   93063 non-null  object
#  15  nivel_de_logro         93063 non-null  object
#  16  dni_participante       92999 non-null  object
#  17  id_participante        93063 non-null  object
#  18  participante           93063 non-null  object
#  19  coordinador_a          93063 non-null  object
#  20  programa               93063 non-null  object
#  21  año_pdl                93063 non-null  object
#  22  socios                 85395 non-null  object
# dtypes: int64(3), object(20)
# memory usage: 16.3+ MB

# %%
df_academico_columns = df_academico.columns
df_academico_columns
# Out:
# Index(['AÑO', 'region_ie', 'provincia_ie', 'ugel_ie', 'distrito_ie',
#        'centropoblado_ie', 'institucion_educativa', 'codigolocal_ie',
#        'codigomodular_ie', 'ruralidad', 'estudiantes', 'grado', 'periodo',
#        'curso', 'comp', 'nivel_de_logro', 'dni_participante',
#        'id_participante', 'participante', 'coordinador_a', 'programa',
#        'año_pdl', 'socios'],
#       dtype='object')

# %%
df_academico_ID_Participante = df_academico['id_participante'].unique()
print(len(df_academico_ID_Participante))
# Out:
# 687

# %% [markdown]
# ### Clima de Aula Dataset

# %%
dataset = 'clima_aula_'
file = f'../data/{dataset}.csv'
df_clima_aula = pd.read_csv(file)

# %%
df_clima_aula.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AÑO                    13200 non-null  int64
#  1   region_ie              13200 non-null  object
#  2   provincia_ie           13200 non-null  object
#  3   ugel_ie                13200 non-null  object
#  4   distrito_ie            13200 non-null  object
#  5   centropoblado_ie       13200 non-null  object
#  6   institucion_educativa  13200 non-null  object
#  7   codigolocal_ie         13200 non-null  int64
#  8   codigomodular_ie       13200 non-null  int64
#  9   ruralidad              13200 non-null  object
#  10  grado                  13200 non-null  object
#  11  periodo                13200 non-null  object
#  12  evaluacion             13200 non-null  object
#  13  elemento               13200 non-null  object
#  14  porcentaje_positivas   13175 non-null  object
#  15  nivel_de_logro         13200 non-null  object
#  16  dni_participante       13186 non-null  object
#  17  id_participante        13200 non-null  object
#  18  participante           13200 non-null  object
#  19  coordinador_a          13200 non-null  object
#  20  programa               13200 non-null  object
#  21  año_pdl                13200 non-null  object
#  22  socios                 13200 non-null  object
# dtypes: int64(3), object(20)
# memory usage: 2.3+ MB

# %%
df_clima_aula_columns = df_clima_aula.columns
df_clima_aula_columns
# Out:
# Index(['AÑO', 'region_ie', 'provincia_ie', 'ugel_ie', 'distrito_ie',
#        'centropoblado_ie', 'institucion_educativa', 'codigolocal_ie',
#        'codigomodular_ie', 'ruralidad', 'grado', 'periodo', 'evaluacion',
#        'elemento', 'porcentaje_positivas', 'nivel_de_logro',
#        'dni_participante', 'id_participante', 'participante', 'coordinador_a',
#        'programa', 'año_pdl', 'socios'],
#       dtype='object')

# %%
df_clima_aula_ID_Participante = df_clima_aula['id_participante'].unique()
print(len(df_clima_aula_ID_Participante))
# Out:
# 449

# %% [markdown]
# ### Socio-emocional Dataset

# %%
dataset = 'socioemocional_'
file = f'../data/{dataset}.csv'
df_socioemocional = pd.read_csv(file)
# Out:
# C:\Users\jange\AppData\Local\Temp\ipykernel_95044\3190278524.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_socioemocional = pd.read_csv(file)

# %%
df_socioemocional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343823 entries, 0 to 343822
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AÑO                    343823 non-null  int64
#  1   region_ie              343823 non-null  object
#  2   provincia_ie           343823 non-null  object
#  3   ugel_ie                343823 non-null  object
#  4   distrito_ie            343823 non-null  object
#  5   centropoblado_ie       343823 non-null  object
#  6   institucion_educativa  343823 non-null  object
#  7   codigolocal_ie         343823 non-null  int64
#  8   codigomodular_ie       343823 non-null  int64
#  9   ruralidad              343823 non-null  object
#  10  id_estudiante          343823 non-null  object
#  11  grado                  343823 non-null  object
#  12  periodo                343823 non-null  object
#  13  evaluación             343823 non-null  object
#  14  habilidad              343823 non-null  object
#  15  promedio               343823 non-null  float64
#  16  nivel_de_logro         343823 non-null  object
#  17  dni_participante       343785 non-null  object
#  18  id_participante        343823 non-null  object
#  19  participantes_sección  343823 non-null  object
#  20  coordinador_a          343823 non-null  object
#  21  programa               343823 non-null  object
#  22  año_pdl                343823 non-null  object
#  23  socios                 343823 non-null  object
# dtypes: float64(1), int64(3), object(20)
# memory usage: 63.0+ MB

# %%
df_socioemocional_columns = df_socioemocional.columns
df_socioemocional_columns
# Out:
# Index(['AÑO', 'region_ie', 'provincia_ie', 'ugel_ie', 'distrito_ie',
#        'centropoblado_ie', 'institucion_educativa', 'codigolocal_ie',
#        'codigomodular_ie', 'ruralidad', 'id_estudiante', 'grado', 'periodo',
#        'evaluación', 'habilidad', 'promedio', 'nivel_de_logro',
#        'dni_participante', 'id_participante', 'participantes_sección',
#        'coordinador_a', 'programa', 'año_pdl', 'socios'],
#       dtype='object')

# %%
df_socioemocional_ID_Participante = df_socioemocional['id_participante'].unique()
print(len(df_socioemocional_ID_Participante))
# Out:
# 450

# %% [markdown]
# ## Agrupamiento y Transformación de Datos

# %% [markdown]
# ACADEMICO - Eliminar registros con valores nulos en esos 3 Primary keys

# %%
df_academico.isnull().sum()
# Out:
# AÑO                         0
# region_ie                   0
# provincia_ie                0
# ugel_ie                     0
# distrito_ie                 0
# centropoblado_ie            0
# institucion_educativa       0
# codigolocal_ie              0
# codigomodular_ie            0
# ruralidad                   0
# estudiantes                 0
# grado                       0
# periodo                     0
# curso                       0
# comp                        0
# nivel_de_logro              0
# dni_participante           64
# id_participante             0
# participante                0
# coordinador_a               0
# programa                    0
# año_pdl                     0
# socios                   7668
# dtype: int64

# %%
df_socioemocional.isnull().sum()
# Out:
# AÑO                       0
# region_ie                 0
# provincia_ie              0
# ugel_ie                   0
# distrito_ie               0
# centropoblado_ie          0
# institucion_educativa     0
# codigolocal_ie            0
# codigomodular_ie          0
# ruralidad                 0
# id_estudiante             0
# grado                     0
# periodo                   0
# evaluación                0
# habilidad                 0
# promedio                  0
# nivel_de_logro            0
# dni_participante         38
# id_participante           0
# participantes_sección     0
# coordinador_a             0
# programa                  0
# año_pdl                   0
# socios                    0
# dtype: int64

# %%
df_clima_aula.isnull().sum()
# Out:
# AÑO                       0
# region_ie                 0
# provincia_ie              0
# ugel_ie                   0
# distrito_ie               0
# centropoblado_ie          0
# institucion_educativa     0
# codigolocal_ie            0
# codigomodular_ie          0
# ruralidad                 0
# grado                     0
# periodo                   0
# evaluacion                0
# elemento                  0
# porcentaje_positivas     25
# nivel_de_logro            0
# dni_participante         14
# id_participante           0
# participante              0
# coordinador_a             0
# programa                  0
# año_pdl                   0
# socios                    0
# dtype: int64

# %%
columns_to_check = ["codigomodular_ie", "grado", "id_participante"]
cleaned_df_aca = df_academico.dropna(subset=columns_to_check)
cleaned_df_aca.id_participante.nunique()
# Out:
# 687

# %%
cleaned_df_aca.columns
# Out:
# Index(['AÑO', 'region_ie', 'provincia_ie', 'ugel_ie', 'distrito_ie',
#        'centropoblado_ie', 'institucion_educativa', 'codigolocal_ie',
#        'codigomodular_ie', 'ruralidad', 'estudiantes', 'grado', 'periodo',
#        'curso', 'comp', 'nivel_de_logro', 'dni_participante',
#        'id_participante', 'participante', 'coordinador_a', 'programa',
#        'año_pdl', 'socios'],
#       dtype='object')

# %% [markdown]
# ACADEMICO - Agrupar por las siguientes columnas y tomar la moda de la variable `Nivel de logro`

# %%
group_cols = ['region_ie', 'provincia_ie ', 'ugel_ie', 'distrito_ie',
       'centropoblado_ie','codigolocal_ie',
       'codigomodular_ie', 'grado', 'periodo','id_participante']

# %%
# Asegurar que los nombres de columnas en group_cols existan en el DataFrame
group_cols = [col.strip() for col in group_cols]  # Elimina espacios extra

# Verificar nombres reales de columnas en cleaned_df_aca
print(cleaned_df_aca.columns)

# Renombrar columnas eliminando espacios extra si existen
cleaned_df_aca.columns = cleaned_df_aca.columns.str.strip()
# Out:
# Index(['AÑO', 'region_ie', 'provincia_ie', 'ugel_ie', 'distrito_ie',
#        'centropoblado_ie', 'institucion_educativa', 'codigolocal_ie',
#        'codigomodular_ie', 'ruralidad', 'estudiantes', 'grado', 'periodo',
#        'curso', 'comp', 'nivel_de_logro', 'dni_participante',
#        'id_participante', 'participante', 'coordinador_a', 'programa',
#        'año_pdl', 'socios'],
#       dtype='object')

# %%
# Aplicar el groupby
if "nivel_de_logro" in cleaned_df_aca.columns:
    result_aca = cleaned_df_aca.groupby(group_cols)["nivel_de_logro"].agg(
        lambda x: x.mode().iloc[0] if not x.mode().empty else None
    ).reset_index()
    print(result_aca)
else:
    print("Error: La columna 'nivel_de_logro' no existe en el DataFrame.")
# Out:
#      region_ie provincia_ie           ugel_ie   distrito_ie  \
# 0     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...        ...          ...               ...           ...
# 1497     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1498     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1499     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1500     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1501     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#          centropoblado_ie  codigolocal_ie  codigomodular_ie     grado  \
# 0                BICHANAK            4178            270363  Primaria
# 1                BICHANAK            4178            270363  Primaria
# 2                   CHAPI            4692            917898  Primaria
# 3                   CHAPI            4692            917898  Primaria
# 4                   CHAPI            4692            917898  Primaria
# ...                   ...             ...               ...       ...
# 1497  SAN MIGUEL DE SEREN          416462            350660  Primaria
# 1498          TAMBOGRANDE          416382            350595  Primaria
# 1499          TAMBOGRANDE          416382            350595  Primaria
# 1500          TAMBOGRANDE          416382            350595  Primaria
# 1501          TAMBOGRANDE          416382            350595  Primaria
#
#              periodo                       id_participante nivel_de_logro
# 0     Diciembre 2024  3a4fbc85-6818-4337-9e42-7b5c27bc432a      En inicio
# 1         Marzo 2024  3a4fbc85-6818-4337-9e42-7b5c27bc432a      En inicio
# 2     Diciembre 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9      En inicio
# 3         Marzo 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9      En inicio
# 4         Marzo 2024  e71d7354-6a2d-4102-a323-df751e484ed0      En inicio
# ...              ...                                   ...            ...
# 1497      Marzo 2024  e20a6064-1bcd-4a9c-8a7b-75addf22g901      En inicio
# 1498  Diciembre 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d  Satisfactorio
# 1499  Diciembre 2024  dfd463e3-a45d-4a28-a442-f08728ea466a      En inicio
# 1500      Marzo 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d     En proceso
# 1501      Marzo 2024  dfd463e3-a45d-4a28-a442-f08728ea466a      En inicio
#
# [1502 rows x 11 columns]

# %%
result_aca
# Out:
#      region_ie provincia_ie           ugel_ie   distrito_ie  \
# 0     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...        ...          ...               ...           ...
# 1497     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1498     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1499     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1500     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1501     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#          centropoblado_ie  codigolocal_ie  codigomodular_ie     grado  \
# 0                BICHANAK            4178            270363  Primaria
# 1                BICHANAK            4178            270363  Primaria
# 2                   CHAPI            4692            917898  Primaria
# 3                   CHAPI            4692            917898  Primaria
# 4                   CHAPI            4692            917898  Primaria
# ...                   ...             ...               ...       ...
# 1497  SAN MIGUEL DE SEREN          416462            350660  Primaria
# 1498          TAMBOGRANDE          416382            350595  Primaria
# 1499          TAMBOGRANDE          416382            350595  Primaria
# 1500          TAMBOGRANDE          416382            350595  Primaria
# 1501          TAMBOGRANDE          416382            350595  Primaria
#
#              periodo                       id_participante nivel_de_logro
# 0     Diciembre 2024  3a4fbc85-6818-4337-9e42-7b5c27bc432a      En inicio
# 1         Marzo 2024  3a4fbc85-6818-4337-9e42-7b5c27bc432a      En inicio
# 2     Diciembre 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9      En inicio
# 3         Marzo 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9      En inicio
# 4         Marzo 2024  e71d7354-6a2d-4102-a323-df751e484ed0      En inicio
# ...              ...                                   ...            ...
# 1497      Marzo 2024  e20a6064-1bcd-4a9c-8a7b-75addf22g901      En inicio
# 1498  Diciembre 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d  Satisfactorio
# 1499  Diciembre 2024  dfd463e3-a45d-4a28-a442-f08728ea466a      En inicio
# 1500      Marzo 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d     En proceso
# 1501      Marzo 2024  dfd463e3-a45d-4a28-a442-f08728ea466a      En inicio
#
# [1502 rows x 11 columns]

# %% [markdown]
# SOCIOEMOCIONAL - Eliminar registros con valores nulos en esos 3 Primary keys

# %%
columns_to_check = ["codigomodular_ie", "grado", "id_participante"]
cleaned_df_soc = df_socioemocional.dropna(subset=columns_to_check)
cleaned_df_soc.id_participante.nunique()
# Out:
# 450

# %%
cleaned_df_soc[cleaned_df_soc.periodo == "Marzo 2023"].habilidad.value_counts()
# Out:
# habilidad
# Autocuidado                                       3223
# Autoestima                                        3058
# Conciencia emocional                              2492
# Comunicación asertiva                             2242
# Trabajo en equipo                                 2241
# Toma de decisiones responsables                   2240
# Regulación emocional                              2238
# Resolución de conflictos                          2237
# Conciencia social                                 2236
# Empatía                                           2233
# Comportamiento prosocial                          2233
# Autoconcepto                                      2192
# Limitados recursos económicos                     1478
# Limitada expectativa sobre la educación           1477
# Violencia escolar                                 1476
# Violencia familiar                                1476
# Consumo de alcohol y drogas                       1475
# Desinformación sobre educación sexual integral    1475
# Ausentismo y deserción escolar                    1474
# Creatividad                                       1474
# Entorno de riesgo                                 1474
# Trabajo adolescente                               1473
# Violencia de género                                808
# Limitada expectativa sobre su proyecto de vida     805
# Percepción sobre estereotipos de género            669
# Name: count, dtype: int64

# %% [markdown]
# SOCIOEMOCIONAL - Agrupar por las columnas anteriores, transformar por Habilidad y tomar la moda de la variable `Nivel de logro` por cada Habilidad

# %%
result = cleaned_df_soc.pivot_table(
    index=group_cols,
    columns="habilidad",
    values="nivel_de_logro",
    aggfunc=lambda x: x.mode().iloc[0] if not x.mode().empty else None
).reset_index()

# %%
result.columns.name = None
result = result.rename_axis(None, axis=1)
result
# Out:
#      region_ie provincia_ie           ugel_ie   distrito_ie  \
# 0     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...        ...          ...               ...           ...
# 1091     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1092     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1093     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1094     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1095     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#          centropoblado_ie  codigolocal_ie  codigomodular_ie       grado  \
# 0                BICHANAK            4178            270363    Primaria
# 1                   CHAPI            4692            917898    Primaria
# 2                CHIRIACO            3800            402271    Primaria
# 3                CHIRIACO            4772            593947  Secundaria
# 4                CHIRIACO            4772            593947  Secundaria
# ...                   ...             ...               ...         ...
# 1091  SAN MIGUEL DE SEREN          416462            350660    Primaria
# 1092          TAMBOGRANDE          416382            350595    Primaria
# 1093          TAMBOGRANDE          416382            350595    Primaria
# 1094          TAMBOGRANDE          416382            350595    Primaria
# 1095          TAMBOGRANDE          416382            350595    Primaria
#
#              periodo                       id_participante  ...  \
# 0     Diciembre 2024  3a4fbc85-6818-4337-9e42-7b5c27bc432a  ...
# 1     Diciembre 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9  ...
# 2     Diciembre 2024  5de9d227-8762-4638-a688-65d357041001  ...
# 3     Diciembre 2023                              0172d360  ...
# 4     Diciembre 2023                              b29b6a82  ...
# ...              ...                                   ...  ...
# 1091      Marzo 2024  f15a6064-3aaa-4a9c-8a7b-74aeec155e92  ...
# 1092  Diciembre 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d  ...
# 1093  Diciembre 2024  dfd463e3-a45d-4a28-a442-f08728ea466a  ...
# 1094      Marzo 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d  ...
# 1095      Marzo 2024  dfd463e3-a45d-4a28-a442-f08728ea466a  ...
#
#      Percepción sobre Estereotipos de género  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1091                                     NaN
# 1092                                     NaN
# 1093                                     NaN
# 1094                                     NaN
# 1095                                     NaN
#
#      Percepción sobre estereotipos de género Regulación emocional  \
# 0                                        NaN            En inicio
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN           En proceso
# 4                                 En proceso        Satisfactorio
# ...                                      ...                  ...
# 1091                                     NaN                  NaN
# 1092                                     NaN                  NaN
# 1093                                     NaN                  NaN
# 1094                                     NaN                  NaN
# 1095                                     NaN                  NaN
#
#      Resolución de conflictos Toma de decisiones responsables  \
# 0                  En proceso                       En inicio
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                  En proceso                   Satisfactorio
# 4               Satisfactorio                   Satisfactorio
# ...                       ...                             ...
# 1091                      NaN                             NaN
# 1092                      NaN                             NaN
# 1093                      NaN                             NaN
# 1094                      NaN                             NaN
# 1095                      NaN                             NaN
#
#      Trabajo adolescente Trabajo en equipo Violencia de género  \
# 0                    NaN        En proceso                 NaN
# 1                    NaN               NaN                 NaN
# 2                    NaN               NaN                 NaN
# 3        Riesgo Moderado        En proceso     Riesgo Moderado
# 4        Riesgo Moderado     Satisfactorio     Riesgo Moderado
# ...                  ...               ...                 ...
# 1091                 NaN               NaN                 NaN
# 1092                 NaN               NaN                 NaN
# 1093                 NaN               NaN                 NaN
# 1094                 NaN               NaN                 NaN
# 1095                 NaN               NaN                 NaN
#
#      Violencia escolar Violencia familiar
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3      Riesgo Moderado    Riesgo Moderado
# 4      Riesgo Moderado    Riesgo Moderado
# ...                ...                ...
# 1091               NaN                NaN
# 1092               NaN                NaN
# 1093               NaN                NaN
# 1094               NaN                NaN
# 1095               NaN                NaN
#
# [1096 rows x 37 columns]

# %% [markdown]
# CLIMA DE AULA - Eliminar registros con valores nulos en esos 3 Primary keys

# %%
columns_to_check = ["codigomodular_ie", "grado", "id_participante"]
cleaned_df_cli = df_clima_aula.dropna(subset=columns_to_check)
cleaned_df_cli.id_participante.nunique()
# Out:
# 449

# %%
cleaned_df_cli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AÑO                    13200 non-null  int64
#  1   region_ie              13200 non-null  object
#  2   provincia_ie           13200 non-null  object
#  3   ugel_ie                13200 non-null  object
#  4   distrito_ie            13200 non-null  object
#  5   centropoblado_ie       13200 non-null  object
#  6   institucion_educativa  13200 non-null  object
#  7   codigolocal_ie         13200 non-null  int64
#  8   codigomodular_ie       13200 non-null  int64
#  9   ruralidad              13200 non-null  object
#  10  grado                  13200 non-null  object
#  11  periodo                13200 non-null  object
#  12  evaluacion             13200 non-null  object
#  13  elemento               13200 non-null  object
#  14  porcentaje_positivas   13175 non-null  object
#  15  nivel_de_logro         13200 non-null  object
#  16  dni_participante       13186 non-null  object
#  17  id_participante        13200 non-null  object
#  18  participante           13200 non-null  object
#  19  coordinador_a          13200 non-null  object
#  20  programa               13200 non-null  object
#  21  año_pdl                13200 non-null  object
#  22  socios                 13200 non-null  object
# dtypes: int64(3), object(20)
# memory usage: 2.3+ MB

# %% [markdown]
# CLIMA DE AULA - Agrupar por las columnas anteriores, transformar por Elemento y tomar la moda de la variable `Nivel de logro` por cada Elemento

# %%
result_cli = cleaned_df_cli.pivot_table(
    index=group_cols,
    columns="elemento",
    values="nivel_de_logro",
    aggfunc=lambda x: x.mode().iloc[0] if not x.mode().empty else None
).reset_index()

# %%
result_cli.columns.name = None
result_cli = result_cli.rename_axis(None, axis=1)
result_cli
# Out:
#      region_ie provincia_ie           ugel_ie   distrito_ie  \
# 0     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4     AMAZONAS        BAGUA   UGEL IBIR-IMAZA         IMAZA
# ...        ...          ...               ...           ...
# 1181     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1182     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1183     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1184     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 1185     PIURA        PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#          centropoblado_ie  codigolocal_ie  codigomodular_ie       grado  \
# 0                   CHAPI            4692            917898    Primaria
# 1                CHIRIACO            4772            593947  Secundaria
# 2                CHIRIACO            4772            593947  Secundaria
# 3                CHIRIACO            4772            593947  Secundaria
# 4                CHIRIACO            4772            593947  Secundaria
# ...                   ...             ...               ...         ...
# 1181  SAN MIGUEL DE SEREN          416462            350660    Primaria
# 1182          TAMBOGRANDE          416382            350595    Primaria
# 1183          TAMBOGRANDE          416382            350595    Primaria
# 1184          TAMBOGRANDE          416382            350595    Primaria
# 1185          TAMBOGRANDE          416382            350595    Primaria
#
#              periodo                       id_participante  \
# 0     Diciembre 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9
# 1     Diciembre 2023                              0172d360
# 2     Diciembre 2023                              b29b6a82
# 3     Diciembre 2024                          b29b378a2024
# 4         Julio 2023                              0172d360
# ...              ...                                   ...
# 1181      Marzo 2024                          b29b6c112024
# 1182  Diciembre 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d
# 1183  Diciembre 2024  dfd463e3-a45d-4a28-a442-f08728ea466a
# 1184      Marzo 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d
# 1185      Marzo 2024  dfd463e3-a45d-4a28-a442-f08728ea466a
#
#      Aprendizaje completamente interiorizado  \
# 0                              Satisfactorio
# 1                                 En proceso
# 2                                 En proceso
# 3                                  En inicio
# 4                              Satisfactorio
# ...                                      ...
# 1181                              En proceso
# 1182                           Satisfactorio
# 1183                           Satisfactorio
# 1184                               En inicio
# 1185                               En inicio
#
#      Comprensión comprobada y asegurada Expectativas rigurosas mantenidas  \
# 0                         Satisfactorio                     Satisfactorio
# 1                         Satisfactorio                     Satisfactorio
# 2                         Satisfactorio                     Satisfactorio
# 3                            En proceso                         En inicio
# 4                            En proceso                     Satisfactorio
# ...                                 ...                               ...
# 1181                         En proceso                     Satisfactorio
# 1182                      Satisfactorio                        En proceso
# 1183                      Satisfactorio                     Satisfactorio
# 1184                         En proceso                        En proceso
# 1185                          En inicio                         En inicio
#
#      Se crea una cultura positiva y un entorno de aprendizaje  \
# 0                                            En proceso
# 1                                                   NaN
# 2                                                   NaN
# 3                                             En inicio
# 4                                                   NaN
# ...                                                 ...
# 1181                                         En proceso
# 1182                                         En proceso
# 1183                                         En proceso
# 1184                                          En inicio
# 1185                                          En inicio
#
#      Se crea una cultura positiva y un entorno de aprendizaje.  \
# 0                                                   NaN
# 1                                             En inicio
# 2                                             En inicio
# 3                                                   NaN
# 4                                             En inicio
# ...                                                 ...
# 1181                                                NaN
# 1182                                                NaN
# 1183                                                NaN
# 1184                                                NaN
# 1185                                                NaN
#
#      Se establece un entorno de aprendizaje atractivo  \
# 0                                          En proceso
# 1                                          En proceso
# 2                                          En proceso
# 3                                          En proceso
# 4                                          En proceso
# ...                                               ...
# 1181                                       En proceso
# 1182                                       En proceso
# 1183                                       En proceso
# 1184                                       En proceso
# 1185                                        En inicio
#
#      Se fomentan relaciones alentadoras y de apoyo  \
# 0                                       En proceso
# 1                                              NaN
# 2                                              NaN
# 3                                        En inicio
# 4                                              NaN
# ...                                            ...
# 1181                                 Satisfactorio
# 1182                                 Satisfactorio
# 1183                                 Satisfactorio
# 1184                                    En proceso
# 1185                                    En proceso
#
#      Se fomentan relaciones alentadoras y de apoyo.  \
# 0                                               NaN
# 1                                     Satisfactorio
# 2                                        En proceso
# 3                                               NaN
# 4                                        En proceso
# ...                                             ...
# 1181                                            NaN
# 1182                                            NaN
# 1183                                            NaN
# 1184                                            NaN
# 1185                                            NaN
#
#      Se valoran los aportes y las ideas de los estudiantes
# 0                                            En proceso
# 1                                         Satisfactorio
# 2                                            En proceso
# 3                                             En inicio
# 4                                            En proceso
# ...                                                 ...
# 1181                                      Satisfactorio
# 1182                                         En proceso
# 1183                                      Satisfactorio
# 1184                                         En proceso
# 1185                                         En proceso
#
# [1186 rows x 19 columns]

# %%
result_cli.isnull().sum()
# Out:
# region_ie                                                      0
# provincia_ie                                                   0
# ugel_ie                                                        0
# distrito_ie                                                    0
# centropoblado_ie                                               0
# codigolocal_ie                                                 0
# codigomodular_ie                                               0
# grado                                                          0
# periodo                                                        0
# id_participante                                                0
# Aprendizaje completamente interiorizado                        0
# Comprensión comprobada y asegurada                             0
# Expectativas rigurosas mantenidas                              0
# Se crea una cultura positiva y un entorno de aprendizaje     729
# Se crea una cultura positiva y un entorno de aprendizaje.    457
# Se establece un entorno de aprendizaje atractivo               0
# Se fomentan relaciones alentadoras y de apoyo                729
# Se fomentan relaciones alentadoras y de apoyo.               457
# Se valoran los aportes y las ideas de los estudiantes          0
# dtype: int64

# %%
result_cli.shape
# Out:
# (1186, 19)

# %% [markdown]
# ## Cruce de Tablas
#
# Cruce por "CodigoModular_IE", "Grado", "ID_Participante" y "Fecha"

# %%
merged_df = result_aca.merge(result, on=["codigomodular_ie", "grado", "id_participante","periodo"], how="inner")
merged_df = merged_df.merge(result_cli, on=["codigomodular_ie", "grado", "id_participante","periodo"], how="inner")
merged_df
# Out:
#     region_ie_x provincia_ie_x         ugel_ie_x distrito_ie_x  \
# 0      AMAZONAS          BAGUA   UGEL IBIR-IMAZA         IMAZA
# 1      AMAZONAS          BAGUA   UGEL IBIR-IMAZA         IMAZA
# 2      AMAZONAS          BAGUA   UGEL IBIR-IMAZA         IMAZA
# 3      AMAZONAS          BAGUA   UGEL IBIR-IMAZA         IMAZA
# 4      AMAZONAS          BAGUA   UGEL IBIR-IMAZA         IMAZA
# ..          ...            ...               ...           ...
# 654       PIURA          PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 655       PIURA          PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 656       PIURA          PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 657       PIURA          PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
# 658       PIURA          PIURA  UGEL TAMBOGRANDE  TAMBO GRANDE
#
#       centropoblado_ie_x  codigolocal_ie_x  codigomodular_ie       grado  \
# 0                  CHAPI              4692            917898    Primaria
# 1               CHIRIACO              4772            593947  Secundaria
# 2               CHIRIACO              4772            593947  Secundaria
# 3               CHIRIACO              4772            593947  Secundaria
# 4               NAZARETH              3999            270041    Primaria
# ..                   ...               ...               ...         ...
# 654  SAN MIGUEL DE SEREN            416462            350660    Primaria
# 655          TAMBOGRANDE            416382            350595    Primaria
# 656          TAMBOGRANDE            416382            350595    Primaria
# 657          TAMBOGRANDE            416382            350595    Primaria
# 658          TAMBOGRANDE            416382            350595    Primaria
#
#             periodo                       id_participante  ... codigolocal_ie  \
# 0    Diciembre 2024  36d87d12-f6f0-44ed-8be9-54334d91fea9  ...           4692
# 1    Diciembre 2024                          b29b378a2024  ...           4772
# 2        Julio 2024                          b29b378a2024  ...           4772
# 3        Marzo 2024                          b29b378a2024  ...           4772
# 4    Diciembre 2024  7920a3d8-3dc9-43f9-b9a2-22ebd31cb23f  ...           3999
# ..              ...                                   ...  ...            ...
# 654      Marzo 2024                          b29b6c112024  ...         416462
# 655  Diciembre 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d  ...         416382
# 656  Diciembre 2024  dfd463e3-a45d-4a28-a442-f08728ea466a  ...         416382
# 657      Marzo 2024  2f1d770e-d09d-40f5-b920-608b90f64d9d  ...         416382
# 658      Marzo 2024  dfd463e3-a45d-4a28-a442-f08728ea466a  ...         416382
#
#     Aprendizaje completamente interiorizado  \
# 0                             Satisfactorio
# 1                                 En inicio
# 2                                 En inicio
# 3                                 En inicio
# 4                                En proceso
# ..                                      ...
# 654                              En proceso
# 655                           Satisfactorio
# 656                           Satisfactorio
# 657                               En inicio
# 658                               En inicio
#
#     Comprensión comprobada y asegurada Expectativas rigurosas mantenidas  \
# 0                        Satisfactorio                     Satisfactorio
# 1                           En proceso                         En inicio
# 2                           En proceso                        En proceso
# 3                           En proceso                         En inicio
# 4                        Satisfactorio                     Satisfactorio
# ..                                 ...                               ...
# 654                         En proceso                     Satisfactorio
# 655                      Satisfactorio                        En proceso
# 656                      Satisfactorio                     Satisfactorio
# 657                         En proceso                        En proceso
# 658                          En inicio                         En inicio
#
#     Se crea una cultura positiva y un entorno de aprendizaje  \
# 0                                           En proceso
# 1                                            En inicio
# 2                                            En inicio
# 3                                            En inicio
# 4                                            En inicio
# ..                                                 ...
# 654                                         En proceso
# 655                                         En proceso
# 656                                         En proceso
# 657                                          En inicio
# 658                                          En inicio
#
#     Se crea una cultura positiva y un entorno de aprendizaje.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 654                                                NaN
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
# 658                                                NaN
#
#      Se establece un entorno de aprendizaje atractivo  \
# 0                                          En proceso
# 1                                          En proceso
# 2                                           En inicio
# 3                                           En inicio
# 4                                          En proceso
# ..                                                ...
# 654                                        En proceso
# 655                                        En proceso
# 656                                        En proceso
# 657                                        En proceso
# 658                                         En inicio
#
#     Se fomentan relaciones alentadoras y de apoyo  \
# 0                                      En proceso
# 1                                       En inicio
# 2                                       En inicio
# 3                                       En inicio
# 4                                   Satisfactorio
# ..                                            ...
# 654                                 Satisfactorio
# 655                                 Satisfactorio
# 656                                 Satisfactorio
# 657                                    En proceso
# 658                                    En proceso
#
#     Se fomentan relaciones alentadoras y de apoyo.  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 654                                            NaN
# 655                                            NaN
# 656                                            NaN
# 657                                            NaN
# 658                                            NaN
#
#     Se valoran los aportes y las ideas de los estudiantes
# 0                                           En proceso
# 1                                            En inicio
# 2                                           En proceso
# 3                                           En proceso
# 4                                        Satisfactorio
# ..                                                 ...
# 654                                      Satisfactorio
# 655                                         En proceso
# 656                                      Satisfactorio
# 657                                         En proceso
# 658                                         En proceso
#
# [659 rows x 59 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659 entries, 0 to 658
# Data columns (total 59 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   region_ie_x                                                659 non-null    object
#  1   provincia_ie_x                                             659 non-null    object
#  2   ugel_ie_x                                                  659 non-null    object
#  3   distrito_ie_x                                              659 non-null    object
#  4   centropoblado_ie_x                                         659 non-null    object
#  5   codigolocal_ie_x                                           659 non-null    int64
#  6   codigomodular_ie                                           659 non-null    int64
#  7   grado                                                      659 non-null    object
#  8   periodo                                                    659 non-null    object
#  9   id_participante                                            659 non-null    object
#  10  nivel_de_logro                                             659 non-null    object
#  11  region_ie_y                                                659 non-null    object
#  12  provincia_ie_y                                             659 non-null    object
#  13  ugel_ie_y                                                  659 non-null    object
#  14  distrito_ie_y                                              659 non-null    object
#  15  centropoblado_ie_y                                         659 non-null    object
#  16  codigolocal_ie_y                                           659 non-null    int64
#  17  Ausentismo y deserción escolar                             195 non-null    object
#  18  Autoconcepto                                               427 non-null    object
#  19  Autocuidado                                                658 non-null    object
#  20  Autoestima                                                 650 non-null    object
#  21  Comportamiento prosocial                                   424 non-null    object
#  22  Comunicación asertiva                                      424 non-null    object
#  23  Conciencia emocional                                       476 non-null    object
#  24  Conciencia social                                          424 non-null    object
#  25  Consumo de alcohol y drogas                                195 non-null    object
#  26  Creatividad                                                195 non-null    object
#  27  Desinformación sobre educación sexual integral             183 non-null    object
#  28  Desinformación sobre educación sexual reproductiva         34 non-null     object
#  29  Empatía                                                    425 non-null    object
#  30  Entorno de riesgo                                          194 non-null    object
#  31  Limitada expectativa sobre la educación                    195 non-null    object
#  32  Limitada expectativa sobre su proyecto de vida             133 non-null    object
#  33  Limitados recursos económicos                              195 non-null    object
#  34  Percepción sobre Estereotipos de género                    34 non-null     object
#  35  Percepción sobre estereotipos de género                    88 non-null     object
#  36  Regulación emocional                                       424 non-null    object
#  37  Resolución de conflictos                                   424 non-null    object
#  38  Toma de decisiones responsables                            424 non-null    object
#  39  Trabajo adolescente                                        195 non-null    object
#  40  Trabajo en equipo                                          424 non-null    object
#  41  Violencia de género                                        133 non-null    object
#  42  Violencia escolar                                          195 non-null    object
#  43  Violencia familiar                                         195 non-null    object
#  44  region_ie                                                  659 non-null    object
#  45  provincia_ie                                               659 non-null    object
#  46  ugel_ie                                                    659 non-null    object
#  47  distrito_ie                                                659 non-null    object
#  48  centropoblado_ie                                           659 non-null    object
#  49  codigolocal_ie                                             659 non-null    int64
#  50  Aprendizaje completamente interiorizado                    659 non-null    object
#  51  Comprensión comprobada y asegurada                         659 non-null    object
#  52  Expectativas rigurosas mantenidas                          659 non-null    object
#  53  Se crea una cultura positiva y un entorno de aprendizaje   234 non-null    object
#  54  Se crea una cultura positiva y un entorno de aprendizaje.  425 non-null    object
#  55  Se establece un entorno de aprendizaje atractivo           659 non-null    object
#  56  Se fomentan relaciones alentadoras y de apoyo              234 non-null    object
#  57  Se fomentan relaciones alentadoras y de apoyo.             425 non-null    object
#  58  Se valoran los aportes y las ideas de los estudiantes      659 non-null    object
# dtypes: int64(4), object(55)
# memory usage: 303.9+ KB

# %%
merged_df.id_participante.nunique()
# Out:
# 283

# %%
merged_df.isnull().sum()
# Out:
# region_ie_x                                                    0
# provincia_ie_x                                                 0
# ugel_ie_x                                                      0
# distrito_ie_x                                                  0
# centropoblado_ie_x                                             0
# codigolocal_ie_x                                               0
# codigomodular_ie                                               0
# grado                                                          0
# periodo                                                        0
# id_participante                                                0
# nivel_de_logro                                                 0
# region_ie_y                                                    0
# provincia_ie_y                                                 0
# ugel_ie_y                                                      0
# distrito_ie_y                                                  0
# centropoblado_ie_y                                             0
# codigolocal_ie_y                                               0
# Ausentismo y deserción escolar                               464
# Autoconcepto                                                 232
# Autocuidado                                                    1
# Autoestima                                                     9
# Comportamiento prosocial                                     235
# Comunicación asertiva                                        235
# Conciencia emocional                                         183
# Conciencia social                                            235
# Consumo de alcohol y drogas                                  464
# Creatividad                                                  464
# Desinformación sobre educación sexual integral               476
# Desinformación sobre educación sexual reproductiva           625
# Empatía                                                      234
# Entorno de riesgo                                            465
# Limitada expectativa sobre la educación                      464
# Limitada expectativa sobre su proyecto de vida               526
# Limitados recursos económicos                                464
# Percepción sobre Estereotipos de género                      625
# Percepción sobre estereotipos de género                      571
# Regulación emocional                                         235
# Resolución de conflictos                                     235
# Toma de decisiones responsables                              235
# Trabajo adolescente                                          464
# Trabajo en equipo                                            235
# Violencia de género                                          526
# Violencia escolar                                            464
# Violencia familiar                                           464
# region_ie                                                      0
# provincia_ie                                                   0
# ugel_ie                                                        0
# distrito_ie                                                    0
# centropoblado_ie                                               0
# codigolocal_ie                                                 0
# Aprendizaje completamente interiorizado                        0
# Comprensión comprobada y asegurada                             0
# Expectativas rigurosas mantenidas                              0
# Se crea una cultura positiva y un entorno de aprendizaje     425
# Se crea una cultura positiva y un entorno de aprendizaje.    234
# Se establece un entorno de aprendizaje atractivo               0
# Se fomentan relaciones alentadoras y de apoyo                425
# Se fomentan relaciones alentadoras y de apoyo.               234
# Se valoran los aportes y las ideas de los estudiantes          0
# dtype: int64

# %%
merged_df.shape
# Out:
# (659, 59)

# %%
for col in merged_df.columns:
    if col.endswith('_x'):
        col_y = col.replace('_x', '_y')
        if merged_df[col].equals(merged_df[col_y]):
            merged_df.drop([col_y], axis=1, inplace=True)
            merged_df = merged_df.rename(columns={col: col[:-2] })

merged_df.head()
# Out:
#   region_ie provincia_ie          ugel_ie distrito_ie centropoblado_ie  \
# 0  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA            CHAPI
# 1  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         CHIRIACO
# 2  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         CHIRIACO
# 3  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         CHIRIACO
# 4  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         NAZARETH
#
#   codigolocal_ie  codigomodular_ie       grado         periodo  \
# 0           4692            917898    Primaria  Diciembre 2024
# 1           4772            593947  Secundaria  Diciembre 2024
# 2           4772            593947  Secundaria      Julio 2024
# 3           4772            593947  Secundaria      Marzo 2024
# 4           3999            270041    Primaria  Diciembre 2024
#
#                         id_participante  ... codigolocal_ie  \
# 0  36d87d12-f6f0-44ed-8be9-54334d91fea9  ...           4692
# 1                          b29b378a2024  ...           4772
# 2                          b29b378a2024  ...           4772
# 3                          b29b378a2024  ...           4772
# 4  7920a3d8-3dc9-43f9-b9a2-22ebd31cb23f  ...           3999
#
#   Aprendizaje completamente interiorizado Comprensión comprobada y asegurada  \
# 0                           Satisfactorio                      Satisfactorio
# 1                               En inicio                         En proceso
# 2                               En inicio                         En proceso
# 3                               En inicio                         En proceso
# 4                              En proceso                      Satisfactorio
#
#   Expectativas rigurosas mantenidas  \
# 0                     Satisfactorio
# 1                         En inicio
# 2                        En proceso
# 3                         En inicio
# 4                     Satisfactorio
#
#   Se crea una cultura positiva y un entorno de aprendizaje  \
# 0                                         En proceso
# 1                                          En inicio
# 2                                          En inicio
# 3                                          En inicio
# 4                                          En inicio
#
#   Se crea una cultura positiva y un entorno de aprendizaje.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Se establece un entorno de aprendizaje atractivo  \
# 0                                       En proceso
# 1                                       En proceso
# 2                                        En inicio
# 3                                        En inicio
# 4                                       En proceso
#
#   Se fomentan relaciones alentadoras y de apoyo  \
# 0                                    En proceso
# 1                                     En inicio
# 2                                     En inicio
# 3                                     En inicio
# 4                                 Satisfactorio
#
#   Se fomentan relaciones alentadoras y de apoyo.  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Se valoran los aportes y las ideas de los estudiantes
# 0                                         En proceso
# 1                                          En inicio
# 2                                         En proceso
# 3                                         En proceso
# 4                                      Satisfactorio
#
# [5 rows x 53 columns]

# %%
merged_df.columns
# Out:
# Index(['region_ie', 'provincia_ie', 'ugel_ie', 'distrito_ie',
#        'centropoblado_ie', 'codigolocal_ie', 'codigomodular_ie', 'grado',
#        'periodo', 'id_participante', 'nivel_de_logro',
#        'Ausentismo y deserción escolar', 'Autoconcepto', 'Autocuidado',
#        'Autoestima', 'Comportamiento prosocial', 'Comunicación asertiva',
#        'Conciencia emocional', 'Conciencia social',
#        'Consumo de alcohol y drogas', 'Creatividad',
#        'Desinformación sobre educación sexual integral',
#        'Desinformación sobre educación sexual reproductiva', 'Empatía',
#        'Entorno de riesgo', 'Limitada expectativa sobre la educación',
#        'Limitada expectativa sobre su proyecto de vida',
#        'Limitados recursos económicos',
#        'Percepción sobre Estereotipos de género',
#        'Percepción sobre estereotipos de género', 'Regulación emocional',
#        'Resolución de conflictos', 'Toma de decisiones responsables',
#        'Trabajo adolescente', 'Trabajo en equipo', 'Violencia de género',
#        'Violencia escolar', 'Violencia familiar', 'region_ie', 'provincia_ie',
#        'ugel_ie', 'distrito_ie', 'centropoblado_ie', 'codigolocal_ie',
#        'Aprendizaje completamente interiorizado',
#        'Comprensión comprobada y asegurada',
#        'Expectativas rigurosas mantenidas',
#        'Se crea una cultura positiva y un entorno de aprendizaje',
#        'Se crea una cultura positiva y un entorno de aprendizaje.',
#        'Se establece un entorno de aprendizaje atractivo',
#        'Se fomentan relaciones alentadoras y de apoyo',
#        'Se fomentan relaciones alentadoras y de apoyo.',
#        'Se valoran los aportes y las ideas de los estudiantes'],
#       dtype='object')

# %%
merged_df.isnull().sum()
# Out:
# region_ie                                                      0
# provincia_ie                                                   0
# ugel_ie                                                        0
# distrito_ie                                                    0
# centropoblado_ie                                               0
# codigolocal_ie                                                 0
# codigomodular_ie                                               0
# grado                                                          0
# periodo                                                        0
# id_participante                                                0
# nivel_de_logro                                                 0
# Ausentismo y deserción escolar                               464
# Autoconcepto                                                 232
# Autocuidado                                                    1
# Autoestima                                                     9
# Comportamiento prosocial                                     235
# Comunicación asertiva                                        235
# Conciencia emocional                                         183
# Conciencia social                                            235
# Consumo de alcohol y drogas                                  464
# Creatividad                                                  464
# Desinformación sobre educación sexual integral               476
# Desinformación sobre educación sexual reproductiva           625
# Empatía                                                      234
# Entorno de riesgo                                            465
# Limitada expectativa sobre la educación                      464
# Limitada expectativa sobre su proyecto de vida               526
# Limitados recursos económicos                                464
# Percepción sobre Estereotipos de género                      625
# Percepción sobre estereotipos de género                      571
# Regulación emocional                                         235
# Resolución de conflictos                                     235
# Toma de decisiones responsables                              235
# Trabajo adolescente                                          464
# Trabajo en equipo                                            235
# Violencia de género                                          526
# Violencia escolar                                            464
# Violencia familiar                                           464
# region_ie                                                      0
# provincia_ie                                                   0
# ugel_ie                                                        0
# distrito_ie                                                    0
# centropoblado_ie                                               0
# codigolocal_ie                                                 0
# Aprendizaje completamente interiorizado                        0
# Comprensión comprobada y asegurada                             0
# Expectativas rigurosas mantenidas                              0
# Se crea una cultura positiva y un entorno de aprendizaje     425
# Se crea una cultura positiva y un entorno de aprendizaje.    234
# Se establece un entorno de aprendizaje atractivo               0
# Se fomentan relaciones alentadoras y de apoyo                425
# Se fomentan relaciones alentadoras y de apoyo.               234
# Se valoran los aportes y las ideas de los estudiantes          0
# dtype: int64

# %%
(merged_df.isnull().sum()/merged_df.shape[0])*100
# Out:
# region_ie                                                     0.000000
# provincia_ie                                                  0.000000
# ugel_ie                                                       0.000000
# distrito_ie                                                   0.000000
# centropoblado_ie                                              0.000000
# codigolocal_ie                                                0.000000
# codigomodular_ie                                              0.000000
# grado                                                         0.000000
# periodo                                                       0.000000
# id_participante                                               0.000000
# nivel_de_logro                                                0.000000
# Ausentismo y deserción escolar                               70.409712
# Autoconcepto                                                 35.204856
# Autocuidado                                                   0.151745
# Autoestima                                                    1.365706
# Comportamiento prosocial                                     35.660091
# Comunicación asertiva                                        35.660091
# Conciencia emocional                                         27.769347
# Conciencia social                                            35.660091
# Consumo de alcohol y drogas                                  70.409712
# Creatividad                                                  70.409712
# Desinformación sobre educación sexual integral               72.230653
# Desinformación sobre educación sexual reproductiva           94.840668
# Empatía                                                      35.508346
# Entorno de riesgo                                            70.561457
# Limitada expectativa sobre la educación                      70.409712
# Limitada expectativa sobre su proyecto de vida               79.817906
# Limitados recursos económicos                                70.409712
# Percepción sobre Estereotipos de género                      94.840668
# Percepción sobre estereotipos de género                      86.646434
# Regulación emocional                                         35.660091
# Resolución de conflictos                                     35.660091
# Toma de decisiones responsables                              35.660091
# Trabajo adolescente                                          70.409712
# Trabajo en equipo                                            35.660091
# Violencia de género                                          79.817906
# Violencia escolar                                            70.409712
# Violencia familiar                                           70.409712
# region_ie                                                     0.000000
# provincia_ie                                                  0.000000
# ugel_ie                                                       0.000000
# distrito_ie                                                   0.000000
# centropoblado_ie                                              0.000000
# codigolocal_ie                                                0.000000
# Aprendizaje completamente interiorizado                       0.000000
# Comprensión comprobada y asegurada                            0.000000
# Expectativas rigurosas mantenidas                             0.000000
# Se crea una cultura positiva y un entorno de aprendizaje     64.491654
# Se crea una cultura positiva y un entorno de aprendizaje.    35.508346
# Se establece un entorno de aprendizaje atractivo              0.000000
# Se fomentan relaciones alentadoras y de apoyo                64.491654
# Se fomentan relaciones alentadoras y de apoyo.               35.508346
# Se valoran los aportes y las ideas de los estudiantes         0.000000
# dtype: float64

# %%
# Calcular el porcentaje de valores nulos por columna
null_percentage = (merged_df.isnull().sum() / merged_df.shape[0]) * 100

# Filtrar columnas con menos del 70% de valores nulos
merged_df = merged_df.loc[:, null_percentage < 70]

# Mostrar las columnas restantes
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659 entries, 0 to 658
# Data columns (total 32 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   region_ie                                                  659 non-null    object
#  1   provincia_ie                                               659 non-null    object
#  2   ugel_ie                                                    659 non-null    object
#  3   distrito_ie                                                659 non-null    object
#  4   centropoblado_ie                                           659 non-null    object
#  5   codigolocal_ie                                             659 non-null    int64
#  6   codigomodular_ie                                           659 non-null    int64
#  7   grado                                                      659 non-null    object
#  8   periodo                                                    659 non-null    object
#  9   id_participante                                            659 non-null    object
#  10  nivel_de_logro                                             659 non-null    object
#  11  Autoconcepto                                               427 non-null    object
#  12  Autocuidado                                                658 non-null    object
#  13  Autoestima                                                 650 non-null    object
#  14  Comportamiento prosocial                                   424 non-null    object
#  15  Comunicación asertiva                                      424 non-null    object
#  16  Conciencia emocional                                       476 non-null    object
#  17  Conciencia social                                          424 non-null    object
#  18  Empatía                                                    425 non-null    object
#  19  Regulación emocional                                       424 non-null    object
#  20  Resolución de conflictos                                   424 non-null    object
#  21  Toma de decisiones responsables                            424 non-null    object
#  22  Trabajo en equipo                                          424 non-null    object
#  23  Aprendizaje completamente interiorizado                    659 non-null    object
#  24  Comprensión comprobada y asegurada                         659 non-null    object
#  25  Expectativas rigurosas mantenidas                          659 non-null    object
#  26  Se crea una cultura positiva y un entorno de aprendizaje   234 non-null    object
#  27  Se crea una cultura positiva y un entorno de aprendizaje.  425 non-null    object
#  28  Se establece un entorno de aprendizaje atractivo           659 non-null    object
#  29  Se fomentan relaciones alentadoras y de apoyo              234 non-null    object
#  30  Se fomentan relaciones alentadoras y de apoyo.             425 non-null    object
#  31  Se valoran los aportes y las ideas de los estudiantes      659 non-null    object
# dtypes: int64(2), object(30)
# memory usage: 164.9+ KB

# %%
# Eliminar columnas duplicadas basándose en el contenido
merged_df = merged_df.loc[:, ~merged_df.T.duplicated()]

# Mostrar las primeras filas para ver el resultado
merged_df.head()
# Out:
#   region_ie provincia_ie          ugel_ie distrito_ie centropoblado_ie  \
# 0  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA            CHAPI
# 1  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         CHIRIACO
# 2  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         CHIRIACO
# 3  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         CHIRIACO
# 4  AMAZONAS        BAGUA  UGEL IBIR-IMAZA       IMAZA         NAZARETH
#
#    codigolocal_ie  codigomodular_ie       grado         periodo  \
# 0            4692            917898    Primaria  Diciembre 2024
# 1            4772            593947  Secundaria  Diciembre 2024
# 2            4772            593947  Secundaria      Julio 2024
# 3            4772            593947  Secundaria      Marzo 2024
# 4            3999            270041    Primaria  Diciembre 2024
#
#                         id_participante  ... Violencia familiar  \
# 0  36d87d12-f6f0-44ed-8be9-54334d91fea9  ...                NaN
# 1                          b29b378a2024  ...    Riesgo moderado
# 2                          b29b378a2024  ...    Riesgo moderado
# 3                          b29b378a2024  ...    Riesgo moderado
# 4  7920a3d8-3dc9-43f9-b9a2-22ebd31cb23f  ...                NaN
#
#   Aprendizaje completamente interiorizado Comprensión comprobada y asegurada  \
# 0                           Satisfactorio                      Satisfactorio
# 1                               En inicio                         En proceso
# 2                               En inicio                         En proceso
# 3                               En inicio                         En proceso
# 4                              En proceso                      Satisfactorio
#
#   Expectativas rigurosas mantenidas  \
# 0                     Satisfactorio
# 1                         En inicio
# 2                        En proceso
# 3                         En inicio
# 4                     Satisfactorio
#
#   Se crea una cultura positiva y un entorno de aprendizaje  \
# 0                                         En proceso
# 1                                          En inicio
# 2                                          En inicio
# 3                                          En inicio
# 4                                          En inicio
#
#   Se crea una cultura positiva y un entorno de aprendizaje.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Se establece un entorno de aprendizaje atractivo  \
# 0                                       En proceso
# 1                                       En proceso
# 2                                        En inicio
# 3                                        En inicio
# 4                                       En proceso
#
#   Se fomentan relaciones alentadoras y de apoyo  \
# 0                                    En proceso
# 1                                     En inicio
# 2                                     En inicio
# 3                                     En inicio
# 4                                 Satisfactorio
#
#   Se fomentan relaciones alentadoras y de apoyo.  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   Se valoran los aportes y las ideas de los estudiantes
# 0                                         En proceso
# 1                                          En inicio
# 2                                         En proceso
# 3                                         En proceso
# 4                                      Satisfactorio
#
# [5 rows x 46 columns]

# %%
merged_df.periodo.unique()
# Out:
# array(['Diciembre 2024', 'Julio 2024', 'Marzo 2024', 'Diciembre 2023',
#        'Julio 2023', 'Marzo 2023'], dtype=object)

# %%
merged_df['nivel_de_logro'].unique()
# Out:
# array(['En inicio', 'En proceso', 'Satisfactorio'], dtype=object)

# %% [markdown]
# ### Preprocessing

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659 entries, 0 to 658
# Data columns (total 46 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   region_ie                                                  659 non-null    object
#  1   provincia_ie                                               659 non-null    object
#  2   ugel_ie                                                    659 non-null    object
#  3   distrito_ie                                                659 non-null    object
#  4   centropoblado_ie                                           659 non-null    object
#  5   codigolocal_ie                                             659 non-null    int64
#  6   codigomodular_ie                                           659 non-null    int64
#  7   grado                                                      659 non-null    object
#  8   periodo                                                    659 non-null    object
#  9   id_participante                                            659 non-null    object
#  10  nivel_de_logro                                             659 non-null    object
#  11  Ausentismo y deserción escolar                             195 non-null    object
#  12  Autoconcepto                                               427 non-null    object
#  13  Autocuidado                                                658 non-null    object
#  14  Autoestima                                                 650 non-null    object
#  15  Comportamiento prosocial                                   424 non-null    object
#  16  Comunicación asertiva                                      424 non-null    object
#  17  Conciencia emocional                                       476 non-null    object
#  18  Conciencia social                                          424 non-null    object
#  19  Consumo de alcohol y drogas                                195 non-null    object
#  20  Creatividad                                                195 non-null    object
#  21  Desinformación sobre educación sexual integral             183 non-null    object
#  22  Desinformación sobre educación sexual reproductiva         34 non-null     object
#  23  Empatía                                                    425 non-null    object
#  24  Entorno de riesgo                                          194 non-null    object
#  25  Limitada expectativa sobre la educación                    195 non-null    object
#  26  Limitada expectativa sobre su proyecto de vida             133 non-null    object
#  27  Limitados recursos económicos                              195 non-null    object
#  28  Percepción sobre estereotipos de género                    88 non-null     object
#  29  Regulación emocional                                       424 non-null    object
#  30  Resolución de conflictos                                   424 non-null    object
#  31  Toma de decisiones responsables                            424 non-null    object
#  32  Trabajo adolescente                                        195 non-null    object
#  33  Trabajo en equipo                                          424 non-null    object
#  34  Violencia de género                                        133 non-null    object
#  35  Violencia escolar                                          195 non-null    object
#  36  Violencia familiar                                         195 non-null    object
#  37  Aprendizaje completamente interiorizado                    659 non-null    object
#  38  Comprensión comprobada y asegurada                         659 non-null    object
#  39  Expectativas rigurosas mantenidas                          659 non-null    object
#  40  Se crea una cultura positiva y un entorno de aprendizaje   234 non-null    object
#  41  Se crea una cultura positiva y un entorno de aprendizaje.  425 non-null    object
#  42  Se establece un entorno de aprendizaje atractivo           659 non-null    object
#  43  Se fomentan relaciones alentadoras y de apoyo              234 non-null    object
#  44  Se fomentan relaciones alentadoras y de apoyo.             425 non-null    object
#  45  Se valoran los aportes y las ideas de los estudiantes      659 non-null    object
# dtypes: int64(2), object(44)
# memory usage: 237.0+ KB

# %%
df = merged_df.copy()

# %%
nivel_mapping = {'Satisfactorio': 2, 'En proceso': 1, 'En inicio': 0}
df['nivel_de_logro_enc'] = df['nivel_de_logro'].map(nivel_mapping)

# %%
target_distribution = df['nivel_de_logro'].value_counts()
encoded_distribution = df['nivel_de_logro_enc'].value_counts()

# %%
print("Target Distribution (Original):")
print(target_distribution)
# Out:
# Target Distribution (Original):
# nivel_de_logro
# En proceso       248
# Satisfactorio    243
# En inicio        168
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
target_distribution.plot(kind='bar', color=['skyblue', 'orange', 'green'])
plt.title("Distribution of Nivel de Logro")
plt.xlabel("Nivel de Logro")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_columns = df.select_dtypes(include=['object']).columns.difference(['Nivel de logro'])

label_encoders = {}  
for col in categorical_columns:
    le = LabelEncoder()
    
    df[col] = df[col].fillna('-1')
    
    df[col] = le.fit_transform(df[col])
    
    label_encoders[col] = le

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 44 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Region_IE                                                  578 non-null    int64
#  1   Provincia_IE                                               578 non-null    int64
#  2   UGEL_IE                                                    578 non-null    int64
#  3   Distrito_IE                                                578 non-null    int64
#  4   CentroPoblado_IE                                           578 non-null    int64
#  5   CodigoLocal_IE                                             578 non-null    float64
#  6   CodigoModular_IE                                           578 non-null    float64
#  7   Grado                                                      578 non-null    int64
#  8   Fecha                                                      578 non-null    int64
#  9   ID_Participante                                            578 non-null    int64
#  10  Nivel de logro                                             578 non-null    object
#  11  Ausentismo y deserción escolar                             578 non-null    int64
#  12  Autoconcepto                                               578 non-null    int64
#  13  Autocuidado                                                578 non-null    int64
#  14  Autoestima                                                 578 non-null    int64
#  15  Comportamiento prosocial                                   578 non-null    int64
#  16  Comunicación asertiva                                      578 non-null    int64
#  17  Conciencia emocional                                       578 non-null    int64
#  18  Conciencia social                                          578 non-null    int64
#  19  Consumo de alcohol y drogas                                578 non-null    int64
#  20  Creatividad                                                578 non-null    int64
#  21  Desinformación sobre educación sexual integral             578 non-null    int64
#  22  Empatía                                                    578 non-null    int64
#  23  Entorno de riesgo                                          578 non-null    int64
#  24  Limitada expectativa sobre la educación                    578 non-null    int64
#  25  Limitada expectativa sobre su proyecto de vida             578 non-null    int64
#  26  Limitados recursos económicos                              578 non-null    int64
#  27  Percepción sobre estereotipos de género                    578 non-null    int64
#  28  Regulación emocional                                       578 non-null    int64
#  29  Resolución de conflictos                                   578 non-null    int64
#  30  Toma de decisiones responsables                            578 non-null    int64
#  31  Trabajo adolescente                                        578 non-null    int64
#  32  Trabajo en equipo                                          578 non-null    int64
#  33  Violencia de género                                        578 non-null    int64
#  34  Violencia escolar                                          578 non-null    int64
#  35  Violencia familiar                                         578 non-null    int64
#  36  Aprendizaje completamente interiorizado                    578 non-null    int64
#  37  Comprensión comprobada y asegurada                         578 non-null    int64
#  38  Expectativas rigurosas mantenidas                          578 non-null    int64
#  39  Se crea una cultura positiva y un entorno de aprendizaje.  578 non-null    int64
#  40  Se establece un entorno de aprendizaje atractivo           578 non-null    int64
#  41  Se fomentan relaciones alentadoras y de apoyo.             578 non-null    int64
#  42  Se valoran los aportes y las ideas de los estudiantes      578 non-null    int64
#  43  Nivel_de_Logro_Encoded                                     578 non-null    int64
# dtypes: float64(2), int64(41), object(1)
# memory usage: 198.8+ KB

# %%
correlation_matrix = df.drop(['Nivel de logro'], axis=1).corr()
correlation_matrix['Nivel_de_Logro_Encoded'].sort_values(ascending=False)
# Out:
# Nivel_de_Logro_Encoded                                       1.000000
# Se establece un entorno de aprendizaje atractivo             0.233372
# Se fomentan relaciones alentadoras y de apoyo.               0.193745
# Comprensión comprobada y asegurada                           0.163472
# Autoestima                                                   0.163321
# Se crea una cultura positiva y un entorno de aprendizaje.    0.159686
# Se valoran los aportes y las ideas de los estudiantes        0.141157
# Autocuidado                                                  0.086994
# Expectativas rigurosas mantenidas                            0.058432
# Aprendizaje completamente interiorizado                      0.050261
# Distrito_IE                                                  0.036364
# ID_Participante                                              0.009253
# Limitada expectativa sobre su proyecto de vida              -0.019848
# CentroPoblado_IE                                            -0.022904
# CodigoLocal_IE                                              -0.023056
# Region_IE                                                   -0.024757
# Violencia de género                                         -0.025197
# Regulación emocional                                        -0.053846
# Conciencia social                                           -0.057051
# Empatía                                                     -0.066970
# Toma de decisiones responsables                             -0.071025
# Resolución de conflictos                                    -0.073946
# Provincia_IE                                                -0.076101
# Autoconcepto                                                -0.085311
# Comunicación asertiva                                       -0.090608
# Conciencia emocional                                        -0.095670
# Trabajo en equipo                                           -0.106854
# UGEL_IE                                                     -0.112764
# Comportamiento prosocial                                    -0.132713
# CodigoModular_IE                                            -0.152677
# Ausentismo y deserción escolar                              -0.165763
# Creatividad                                                 -0.169133
# Grado                                                       -0.176993
# Violencia familiar                                          -0.179051
# Consumo de alcohol y drogas                                 -0.183664
# Entorno de riesgo                                           -0.184841
# Violencia escolar                                           -0.190987
# Limitada expectativa sobre la educación                     -0.192461
# Trabajo adolescente                                         -0.196349
# Desinformación sobre educación sexual integral              -0.196602
# Limitados recursos económicos                               -0.198518
# Percepción sobre estereotipos de género                     -0.226321
# Fecha                                                       -0.331397
# Name: Nivel_de_Logro_Encoded, dtype: float64

# %%
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', cbar=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Modelling

# %%
df.columns
# Out:
# Index(['Region_IE', 'Provincia_IE', 'UGEL_IE', 'Distrito_IE',
#        'CentroPoblado_IE', 'CodigoLocal_IE', 'CodigoModular_IE', 'Grado',
#        'Fecha', 'ID_Participante', 'Nivel de logro',
#        'Ausentismo y deserción escolar', 'Autoconcepto', 'Autocuidado',
#        'Autoestima', 'Comportamiento prosocial', 'Comunicación asertiva',
#        'Conciencia emocional', 'Conciencia social',
#        'Consumo de alcohol y drogas', 'Creatividad',
#        'Desinformación sobre educación sexual integral', 'Empatía',
#        'Entorno de riesgo', 'Limitada expectativa sobre la educación',
#        'Limitada expectativa sobre su proyecto de vida',
#        'Limitados recursos económicos',
#        'Percepción sobre estereotipos de género', 'Regulación emocional',
#        'Resolución de conflictos', 'Toma de decisiones responsables',
#        'Trabajo adolescente', 'Trabajo en equipo', 'Violencia de género',
#        'Violencia escolar', 'Violencia familiar',
#        'Aprendizaje completamente interiorizado',
#        'Comprensión comprobada y asegurada',
#        'Expectativas rigurosas mantenidas',
#        'Se crea una cultura positiva y un entorno de aprendizaje.',
#        'Se establece un entorno de aprendizaje atractivo',
#        'Se fomentan relaciones alentadoras y de apoyo.',
#        'Se valoran los aportes y las ideas de los estudiantes',
#        'Nivel_de_Logro_Encoded'],
#       dtype='object')

# %% [markdown]
# Por agregar indice de fechas
# Eliminar Primary keys de tablas, indices de escuela o region (se podria agrupar por regiones de calor, frio y Lima)
# Esperar por la data demografica de alumnos o escuela
# Esperar por la historia de 2024

# %%
X = df.drop(columns=['Nivel de logro', 'Nivel_de_Logro_Encoded', 'Region_IE', 'Provincia_IE', 'UGEL_IE', 'Distrito_IE', 'CentroPoblado_IE', 'CodigoLocal_IE', 'CodigoModular_IE', 'ID_Participante', 'Fecha'])
y = df['Nivel_de_Logro_Encoded']

# %%
y_binary = (y == 2).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_binary, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestClassifier(random_state=42, n_estimators=100, max_depth=5)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, random_state=42)

# %%
# Evaluate the model
y_pred = rf_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6551724137931034
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69        63
#            1       0.63      0.60      0.62        53
#
#     accuracy                           0.66       116
#    macro avg       0.65      0.65      0.65       116
# weighted avg       0.65      0.66      0.65       116

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5)
grid_search.fit(X, y)
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}

# %%
rf_model_tuned = RandomForestClassifier(random_state=42, n_estimators=50, max_depth=5, min_samples_split=2)
rf_model_tuned.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=50, random_state=42)

# %% [markdown]
# ### Evaluation

# %%
feature_importances = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

# %%
print("Top Features:")
print(feature_importances.head(20))
# Out:
# Top Features:
#                                               Feature  Importance
# 0                                               Grado    0.170795
# 30   Se establece un entorno de aprendizaje atractivo    0.050511
# 17            Percepción sobre estereotipos de género    0.049893
# 21                                Trabajo adolescente    0.042923
# 11     Desinformación sobre educación sexual integral    0.038485
# 19                           Resolución de conflictos    0.038434
# 3                                         Autocuidado    0.037746
# 12                                            Empatía    0.035726
# 18                               Regulación emocional    0.035424
# 7                                Conciencia emocional    0.035092
# 1                      Ausentismo y deserción escolar    0.029729
# 32  Se valoran los aportes y las ideas de los estu...    0.029423
# 31     Se fomentan relaciones alentadoras y de apoyo.    0.028523
# 4                                          Autoestima    0.026727
# 14            Limitada expectativa sobre la educación    0.026478
# 27                 Comprensión comprobada y asegurada    0.026097
# 16                      Limitados recursos económicos    0.026039
# 28                  Expectativas rigurosas mantenidas    0.025876
# 29  Se crea una cultura positiva y un entorno de a...    0.023867
# 24                                  Violencia escolar    0.022801
